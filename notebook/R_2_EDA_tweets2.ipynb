# %% [markdown]
# # R_2 Through EDA of 65 GB tweets

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("COMP90024_A2_EDA")
    .config("spark.sql.repl.eagerEval.enabled", True)
    .config("spark.sql.parquet.cacheMetadata", "true")
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/23 12:22:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read In Original
spark_json = spark.read.json('../data/raw/BigTwitterFile/twitter-huge.json')

# %%
# Observe Schema
spark_json.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- doc: struct (nullable = true)
#  |    |-- _id: string (nullable = true)
#  |    |-- _rev: string (nullable = true)
#  |    |-- data: struct (nullable = true)
#  |    |    |-- author_id: string (nullable = true)
#  |    |    |-- context_annotations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- domain: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- entity: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- conversation_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- annotations: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- normalized_text: string (nullable = true)
#  |    |    |    |    |    |-- probability: double (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- cashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- tag: string (nullable = true)
#  |    |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- tag: string (nullable = true)
#  |    |    |    |-- mentions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- username: string (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- media_key: string (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- status: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- unwound_url: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: struct (nullable = true)
#  |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- place_id: string (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- public_metrics: struct (nullable = true)
#  |    |    |    |-- like_count: long (nullable = true)
#  |    |    |    |-- quote_count: long (nullable = true)
#  |    |    |    |-- reply_count: long (nullable = true)
#  |    |    |    |-- retweet_count: long (nullable = true)
#  |    |    |-- sentiment: double (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- withheld: struct (nullable = true)
#  |    |    |    |-- copyright: boolean (nullable = true)
#  |    |    |    |-- country_codes: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- includes: string (nullable = true)
#  |    |-- matching_rules: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- tag: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- key: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- value: struct (nullable = true)
#  |    |-- tags: string (nullable = true)
#  |    |-- tokens: string (nullable = true)

# %% [markdown]
# ### Extract Key Columns

# %%
# important features to extract out of the original dataframe
out_df = spark_json.select('doc._id', 'doc.data.created_at', 'doc.data.geo.coordinates.coordinates', 
                  'doc.data.geo.coordinates.type', 'doc.includes', 
                  'doc.data.geo.place_id', 'doc.data.lang', 'doc.data.sentiment', 'doc.data.text', 
                  'doc.data.author_id')

# %% [markdown]
# ### Missing Geolocation

# %%
# observe missing values in 'includes' (geolocation)


from pyspark.sql.functions import col, sum

def count_missing_values(df, column_name):
    # Filter the DataFrame to select rows where the column is null
    filtered_df = df.filter(col(column_name).isNull())
    
    # Use the `sum()` function to count the number of rows with null values
    count = filtered_df.select(sum(col(column_name).isNull().cast("int"))).collect()[0][0]
    
    return count

missing_count = count_missing_values(out_df, "includes")

# %%
missing_count
# Out:
# 49300230

# %%
out_df.count()
# Out:
# 52533743

# %%
52533743 - 49300230
# Out:
# 3233513

# %% [markdown]
# ### Extract Tweets containing AI Keywords

# %%
import pandas as pd
words_df = pd.read_excel('../data/raw/Keywords/AI_keywords1.xlsx')

words = []
for col in words_df.columns:
    if col != 'Medical diagnosis':
        words.extend(list(words_df[col]))

words_df2 = pd.read_excel('../data/raw/Keywords/AI_keywords2.xlsx')

words2 = [word.split('.')[1].strip() for word in words_df2['words']]
words.extend(words2)
words = [word.strip() for word in words]
words.extend([' ai ', ' AI '])

# %%
# Only get tweets that contain AI related keywords

from pyspark.sql.functions import col

# Assume 'df' is your DataFrame with a string typed column named 'text'
filter_cond = col('doc.data.text').contains(words[0])  # initial filter condition

for i in range(1, len(words)):
    filter_cond = filter_cond | col('text').contains(words[i])  # add each snippet to the filter condition using the & operator

filtered_df = out_df.filter(filter_cond)  # apply the filter condition to the DataFrame

# %%
# convert to Pandas df
df = filtered_df.select("*").toPandas()

# %%
df
# Out:
#                          _id                created_at coordinates  type  \
# 0        1491845931456774147  2022-02-10T18:46:01.000Z        None  None
# 1        1491846139196452864  2022-02-10T18:46:51.000Z        None  None
# 2        1491817025433489409  2022-02-10T16:51:10.000Z        None  None
# 3        1491844343379992579  2022-02-10T18:39:43.000Z        None  None
# 4        1491814800212611079  2022-02-10T16:42:19.000Z        None  None
# ...                      ...                       ...         ...   ...
# 1074884  1557516967275528193  2022-08-10T23:59:16.000Z        None  None
# 1074885  1557517000686968832  2022-08-10T23:59:24.000Z        None  None
# 1074886  1557517101694611457  2022-08-10T23:59:48.000Z        None  None
# 1074887  1557517147898781701  2022-08-10T23:59:59.000Z        None  None
# 1074888  1557513412393185280  2022-08-10T23:45:09.000Z        None  None
#
#                                                   includes          place_id  \
# 0                                                     None              None
# 1                                                     None              None
# 2                                                     None              None
# 3                                                     None              None
# 4                                                     None              None
# ...                                                    ...               ...
# 1074884                                               None              None
# 1074885  {"places":[{"full_name":"Brisbane, Queensland"...  004ec16c62325149
# 1074886                                               None              None
# 1074887                                               None              None
# 1074888                                               None              None
#
#         lang  sentiment                                               text  \
# 0         en   0.020408  @Real_DrugTalk DL Down3r´s hit inspirational s...
# 1         en   0.020408  @Real_DrugTalk DL Down3r´s hit inspirational s...
# 2         en   0.020833  @slavetothehat DL Down3r´s hit inspirational s...
# 3         en   0.020408  @jots_8 DL Down3r´s hit inspirational song " S...
# 4         en   0.020833  @badwool9 DL Down3r´s hit inspirational song "...
# ...      ...        ...                                                ...
# 1074884   en   0.000000  🇦🇺👏 A great day for the Aussies at the #Canadi...
# 1074885   en  -0.162791  I'm listening to the  "eDNA monitoring; 'teleh...
# 1074886   en   0.000000  GBP/USD\nTARGET LEVEL 1.2233\nSL: (B) 1.2199 4...
# 1074887   en   0.120000  AI tech allows businesses to gather and utilis...
# 1074888   en   0.000000  @jhgates1 @benmooreau @ncdave4life @agentsinac...
#
#                   author_id
# 0                  62407961
# 1                  62407961
# 2                  62407961
# 3                  62407961
# 4                  62407961
# ...                     ...
# 1074884            43806353
# 1074885  876592795963736064
# 1074886          1115918534
# 1074887           223309438
# 1074888          3316708940
#
# [1074889 rows x 10 columns]

# %% [markdown]
# ### Previously keywords file also included 'ai', so now try to do only ' ai ' so not to match tweets containing e.g. 'again'

# %%
def AI_bool(input, words=words):

    for word in words:
        if ''+word+'' in input:
            return 1
    return 0

df['ai_bool'] = df['text'].apply(AI_bool)

# %%
# number of 'real AI related' tweets and has useable geolocation
len(df[(~df['includes'].isnull()) & (df['ai_bool'] == 1)])
# Out:
# 49952

# %%
# number of 'real AI related' tweets
len(df[df['ai_bool'] == 1])
# Out:
# 821477

# %%
# observes some of these real AI related tweet

i = 0
for txt in df[(~df['includes'].isnull()) & (df['ai_bool'] == 1)]['text']:
    print(txt)
    print('==')
    i += 1

    if i == 200:
        break

# HOWEVER, DOESN'T SEEM TO HAVE ACTUALLY MATCHED
# Out:
# @NftAndromeda88 @staratlas @romeguild Guys don’t forget that to participate , you need to write a FUNNY DAO proposal … use your imagination 💭
# ==
# @commentiquette MLB@mtplkwvlggelkikjj https://t.co/YCqUT4AFga
# ==
# @Cold_Behavior @Cold_Behavior CAUSING A BLIZZARD🌬❄️! Less get it BAYBAY!!!
# @H0DLRR @tha_kid_oldwun @JarrodPeka @tthugsmemes @its_DZR @NftP1ug @dezza4034 join 👉 https://t.co/Kpp2foVaXH👈 use code: BKBaLT https://t.co/pTOmLgkcDX
# ==
# @AdamBandt @AdamBandt if these education institutions are really where it's at with God, they would know that Church is NOT a place for Christians, it's for Sinners, and ALL SINNERS are welcome. God judges, not us
# ==
# @TThugsNFT @tthugsmemes @H0DLRR @KryptTThugs
# ==
# @ShoebridgeMLC What else could Labor do? Today shows they took the right approach! They found a middle ground for LNP members to cross the floor and to then put it back on LNP to see how they would push it threw! LNP then have to ask is it worth it?
# ==
# @ML3democrats @TinaTu1966 👍magnifique
# ==
# @markstrahl Indeed @CeliaHammond @MiaDaviesMLA
# ==
# @lindy2350 Most of the times I've tried to access healthcare.
# ==
# @samopic @AdamBandt Could have just voted it down. No is good. Whose votes would they lose? A few bigots who probably vote LNP anyhow as that's where the old DLP seems to have ended up.
# ==
# Rather hurling childish insults at the MLA in question perhaps the moronic #IStandWithDan crew could take a moment to consider how rotten things are under Andrews that a sitting Labor member would want to cross the floor. Maybe the real rat is the bloke in charge.
# ==
# @de_uql Cont:anyone who lives nearby.Looks like a magic carpet.And ♂️s stay in dune regeneration area,so u get lil'iridescent gems flashing in amongst brown dried out plants(?)Agen-MAGIC🤩Folks miss free nature shows-just walk past-un.b.levable🌟💎
# ==
# @WildColonial05 @FOXNRL Ok...
# ==
# @Narty0071 @WeAreAllVIPs It's reminds me of Forrest Gump when he addresses his wife, JENNNY 😒
# ==
# https://t.co/sqt6Cq0bML
# God must know they just made up the name Jesus as a scam back 2022 years ago. By then all the fucking peasants had forgotten about me.Daniel.200 years and they forgot&amp;worshipped a false Messiah for the past 2000 years. That's sly
# https://t.co/GtqrBjWQNx https://t.co/4QU6PilByT
# ==
# @AusFedPolice @ReeceKershawAPM @ABarrMLA @CBRProgressives @GreensACT @actlawsociety @NSWBar @ICAN_NSW @nswpolice @LiberalNSW @LiberalAus @SenatorCash @lindareynoldswa @Anne_Ruston @MarisePayne @SenSHenderson @MathiasCormann @SenScottRyan Are the police 👮‍♀️ going to interview https://t.co/1hmV6fDJCS
# ==
# BREAKING: Tasmania’s Education Minister Sarah Courtney has resigned from parliament &amp; cabinet. @WINNews_Tas #politas
# ==
# @pilarvelasquezv https://t.co/NFpYkDLz2A
# ==
# Don’t talk about how unsafe my workplace is when someone was raped in Parliament House. The reality is there are NO safe jobs for women because the WORLD isn’t, in its current state, safe for women
# ==
# Hey @SamanthaRatnam @FionaPattenMLC is the gallery open? I want to watch the debate in person.
#
# @VicParliament information on how to attend a sitting is not available   here &gt;&gt; https://t.co/j8elSDZUY5
#
# @VictoriaPolice turned me away saying it's closed, but I cannot see a notice. https://t.co/KwMY56YoH4
# ==
# @VicParliament Thank you. Could that detail be made clear on the visit parliament section, and a subheading for the gallery be added?
# I understand that general public attendees with passes from MLCs and MPs can view sittings in the gallery, is that correct?
# ==
# @Pauljneilson191 FML. Been tired this week but not much else until last night I realized I couldn’t smell anything from shower products
# ==
# Grace needs YOUR help!! Let's get her over to the UK to fly the flag for Aus! https://t.co/IRLZ1UNiTp
# ==
# @jrabbott1 @NRL @AFL Bunnies 💚❤🖤 🐇
# ==
# @jrabbott1 @NRL @AFL Hot tip - not the Eels.
# ==
# @jrabbott1 @NRL @AFL @jrabbott1 whats your NFL team and we will tell you the NRL equivalent
# ==
# @jrabbott1 @NRL @AFL Storm all the way
# ==
# @Katzo60 @jrabbott1 @NRL @AFL @Schoolparade @Rightonoworries commonly
# ==
# @jrabbott1 @NRL @AFL I feel a @storm brewing
# ==
# @jrabbott1 @NRL @AFL Indy and Calgary points me to Manly
# ==
# @jrabbott1 @OOOL1908 @NRL @AFL Bulldogs. Blue and white strip. Great history, coming back from years of no success. Watch the fightback and enjoy.
# ==
# ==
# 1/3 Quality and reliable Personalised #CancerMonitoring  also plugs in nicely into the managing algorithms for these #Cancer patients.
# ==
# Pretty much this https://t.co/ZrqPDLX2CL
# ==
# DSS 34 carrier lock on Advanced Composition Explorer
# Frequency: 2.2784GHz
# Signal strength: -142dBm
# IDLE OFF 1 MCD2
# ==
# We lift up Donny before You Lord, Make him aware of ur presence and love, may ur arms embrace Donny at all times.Bless his heart,life,health, family,work, finances,projects &amp; his future Lord.
#
# HAPPY DONNY DAY
#
# #DonnyPangilinan
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY https://t.co/9EIEjdXxmE
# ==
# Roller skating w these 2 @jaclynwitchery @gemstonewake .
# .
# .
# .
# .
# .
# .
# #byronbaylife #skatergirl #rollerskating #rollerskate #wheelsanddolls #rollerbabes #myarsehurts @ Suffolk Park https://t.co/aC5FTEw3ML
# ==
# https://t.co/Rqzc0SeDLg
# ==
# @NeilEvansmail Oh Yesssssss Prez! #PIRC #WINNING #JoinTheClub https://t.co/VdxCbk9bIG
# ==
# 🚨MATCH ANNOUNCEMENT🚨
#
# MAYHEM in the MARSH - REVENGE:
#
# Stephen Valek
# V
# ‘The Dreamtime Voodoo Witch’
# Erika Reid
#
# Tix: https://t.co/axdjEfq5GX
#
# SAT March 19, 2022
# Bacchus Marsh Public Hall
#
# #MITMRevenge
#
# Watch our previous events
# https://t.co/YvL0TBfAbv https://t.co/rwrVL3QqYf
# ==
# @MLoParis I love my pharmacist. When I fainted in there a few weeks ago he was great. He’s doing my flu shot when it’s due. He deals with Mum and he dealt with my Dad to. He asked me how I was going in regards to that and I said day by day.
# ==
# @MLoParis I think if you get a great pharmacist it’s half the battle.
# ==
# @MLoParis I’m always there as is Mum. Between us they make a fortune.
# ==
# @FionaPattenMLC @YouTube “It decriminalises consenting sex acts between consenting adults” this made me shiver. Thank you for your work!
# ==
# What a disgrace https://t.co/aMLY4zeC8a
# ==
# @NRLSCTalk Mark Geyer is coming on the pod? About time!
# ==
# SURPRISE!!! YERGURL WILL BE PLAYING A SET AT OUR CLUB NIGHT AT YAH YAH’S TOMORROW NIGHT, SEE YOU THERE ☻
# https://t.co/QYq5WAj3c4 https://t.co/LMqbo5LGNl
# ==
# @MLoParis @catherine___c I have had my booster. No more. I’ve done enough now. 3 jabs is enough especially now Dad has passed away. I said to Mum no more and she said that’s fair enough.
# ==
# @ScottMorrisonMP Rest leave wage parity with nsw public hospitals nurses immediatelyRegistered Nurse Agedcare Billions foreignaid to Indonesia who slaughter West Papuans @PRIME7NewsCW @WINNEWS_CW @lithgowmercury @LithgowNSW @TheLithgowVoice @MudgeeGuardian
# https://t.co/U3iM11MBV6
# ==
# This is tonight! Find out how you can help track you local mosquitoes for #mozziemonth 🔎📓🦟 https://t.co/3MLjXyRR9n
# ==
# Vale Olsen Filipaina. A true Pacific trailblazer and a @NZRL_Kiwis legend. He paved the way for so many. Rest in peace.
# ==
# @GlennMSMITH1 @NZRL_Kiwis That's true mate yes.
# ==
# ==
# @Marriott aims for a century with its suite of hotel openings across Asia Pacific this year. Here's just some of what's in store. 🛌
#
# #marriotthotels #news #hotels
# https://t.co/YDLeKKmsZw
# ==
# Sexy Ârse Lolita’s out on dià ffvorgÿ Sportanzaniahhhhh Ârsexplaÿtîmès” 💖💖🧡💜💜💜💚🧡🧡🧡💜💚💚💚💜🧡🧡🧡💚💜💜💜🧡💖💖🧡
# 💖💜💖💜💖🧡💖🧡💖💜💖💜💖
# 💖💖💜💖🧡💖💚💖🧡💖💜💖💖
# 💖💜💖💜💖🧡💖🧡💖💜💖💜💖j https://t.co/qtLfdeMLyP
# ==
# @FionaPattenMLC Congrats Fiona for all your very hard work - what a journey it’s been!
# ==
# @PRGuy17 @FionaPattenMLC A means to an end?
# ==
# @FionaPattenMLC Today forty two years ago I landed in Vic Melbourne  airport, from Italy as an Albanian refugee.
# Now fore the last seven years I have been kidnapped by the evil Australian grubs rapist terror coalition liberal government, unlawfully illegally. https://t.co/rrhR9gADzy
# ==
# She did a great job on this massacre
# https://t.co/uIxqti8inL I got the evidence "‘Killed like animals’: documents reveal how Australia turned a blind eye to a West Papuan massacre | Australian foreign policy | The Guardian" https://t.co/SGRYp2MLVC https://t.co/N5saiOR0nH https://t.co/iQYNfwZNHw
# ==
# Congratulations @FionaPattenMLC https://t.co/WXnlPKJCs6
# ==
# @leighsales  Did a great story on this massacre https://t.co/uIxqti8inL I got the evidence . Criminals "‘Killed like animals’: documents reveal how Australia turned a blind eye to a West Papuan massacre | Australian foreign policy | The Guardian" https://t.co/SGRYp2MLVC https://t.co/snAiPruCVu
# ==
# Yep and to explain to the International Criminal Court  covering up war crimes for Indonesia in West Papua "‘Killed like animals’: documents reveal how Australia turned a blind eye to a West Papuan massacre | Australian foreign policy | The Guardian" https://t.co/SGRYp2MLVC https://t.co/6PoiRIJOQC https://t.co/u9WYhAgI4Z
# ==
# Censorship on West Papua slaughter by Indonesian military shocking "‘Killed like animals’: documents reveal how Australia turned a blind eye to a West Papuan massacre | Australian foreign policy | The Guardian" https://t.co/SGRYp2MLVC https://t.co/CEDnZEspN4
# ==
# Thanks for all your efforts on West Papua  much appreciated Anthony
# "‘Killed like animals’: documents reveal how Australia turned a blind eye to a West Papuan massacre | Australian foreign policy | The Guardian" https://t.co/SGRYp2MLVC https://t.co/7gbFtqopCa https://t.co/lmO3hbcIPc
# ==
# Quick shout out to @nthqldcowboys fans and Townsvillians in general.
#
# What's accommodation like around QCB Stadium?
#
# Planning a trip up there in May when the Knights come to town.
#
# Any help (ie hints, do's and don'ts) appreciated.
#
# TIA!
#
# #NRL #ridemcowboys
# ==
# @FNRLTheBlog @FourFourTwo Comedy gold
# ==
# we love you big time our best boy ❤️❤️❤️
#
# HAPPY DONNY DAY
#
# #DonnyPangilinan
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY https://t.co/39jzH0SUzd
# ==
# @MLoParis My medication is being changed now because of my PTSD. I also have OCD and since Dad died it’s ramped up. I kept it pushed aside until last week I couldn’t take it anymore so I told my doctor.
# ==
# @MLoParis I don’t feel patronised because you’re right … I know when things aren’t going well. My family have been magnificent. And because I hide things a lot they had no idea how I was suffering. They do now.
# ==
# @MLoParis I will say it’s always the people (you) with a beautiful heart that always get shite on. And that’s a fact.
# ==
# @MLoParis I’ll be there for people always until I’m given a reason not to. Then I’m gone. If I can be there and I can help, I will ❤️
# ==
# ahhh okkkkkkk 👀👀👀
#
# HAPPY DONNY DAY
#
# #DonnyPangilinan
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY https://t.co/OCMuY0igFd
# ==
# haiyaa~ I think I will come to see uncle roger la https://t.co/AJRSxaMLcT
# ==
# DSS 36 carrier lock on THEMIS C
# Frequency: 2.2825GHz
# Signal strength: -121dBm
# IDLE OFF 1 MCD2
# ==
# Good!
#
# ATAGI recommends change to definition of COVID-19 vaccine status from 'fully vaccinated' to 'up to date'
# https://t.co/3C1zkcrNkT
# ==
# I chose Jessica Chastain over Nicole Kidman!
# I know I’m a bad Aussie now but I can’t deny the fact that Jessica Chastain truly CHANNELED Tammy Faye!
# Praise God! 😭😭😭🙏#OscarNoms #Oscars https://t.co/kEkcamBXP1 https://t.co/nhASsgl4FG
# ==
# ATAGI recommend scrapping the term “fully vaccinated” &amp; replace with being “up to date” in a COVID vaccine schedule.
#
# An important distinction that stops people thinking 2 dosss give them lifetime protection when we’re nowhere near the end of this thing.
#
# https://t.co/wOaNTlktNA
# ==
# Australia leads world on standing up to China, Blinken says https://t.co/f606VghRLS
# ==
# https://t.co/RLJX776kcK
#
# Too bad Facebook is ran by the Nazis as they block me there. We could have had a really hilarious vote on which tradegy cums up next in my asscrack. The galaxy must be fucking laughing themselves silly at our evil microwinded world leadership by now https://t.co/zr7ubdYziH
# ==
# CCM 3️⃣-3️⃣ MAC
#
# I need a breather after that! Fantastic fight back from the Mariners, but two absolute WORLDIES from the Bulls. #CCMvMAC https://t.co/YfQrugXWNx
# ==
# Download the @dabblecomau app today and follow us for our free tips on our dabble page. #Sportsbetting #bettingtips #betting #NRL #AFL #NFL #NBA #sportsbet #gambling #gamblingtips #ausbettips #ausbettingtips #australianbettips #bettingadvice #sports https://t.co/1nuiSq46lX
# ==
# First look at how our tips will be delivered to members. Stay tuned for more updates.#Sportsbetting #bettingtips #betting #NRL #AFL #NFL #NBA #sportsbet #gambling #gamblingtips #ausbettips #ausbettingtips #australianbettips #bettingadvice #sports https://t.co/9AXHpr0aex
# ==
# ang perfect mo 🥺😭
#
# HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# Ate @keiaaemielle 's story https://t.co/srGiyFqxOM
# ==
# @WH0LEN3WW0RLD Sorry to hear that Thomas
# ==
# @dzonbel @bubblycara_ HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @loveELLEBNOD @ForDonatoOnly HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# INNR — What end of 20-year war brings to Afghan women: She and her husband rely on casual farm work and aid handouts to get by, including from the new Taliban rulers. "I am worried about my daily expenses.
#
# View article... https://t.co/MN9SqYKerl
# ==
# INNR — Declining Maternal and Child Nutrition in Low-and Middle-Income Countries: Adequate nutrition in the perinatal period is essential for healthy ... up to 4.8 million pregnant women may develop anemia and 3 million may give ...
#
# View article... https://t.co/s3xWmgTwSl
# ==
# INNR — AI patient room automation introduced in India: "There is a huge potential for AutoMaid to bring about a paradigm shift in the healthcare system with contactless health monitoring and an AI-based ...
#
# View article... https://t.co/G0s9tvC5jY
# ==
# Wow. Bronwyn Bishop rises again 😱😱😱 https://t.co/WcNNkgKEt7
# ==
# @tagsenchemistry @ChElsy082807 @donnypangilinan @bellemariano02 HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @db_happyypill HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @MyBabolBondelle HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# napa-smile ka din nya ng ganito, higit pa nga eh. kaya mag reply ka, i-retweet mo na din at i-requote mo na to . DESERVE 1M ni Nato ❤️🖤
#
# HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan https://t.co/8S1laRGRWK
# ==
# @DonBelleGlobal i love him because I love him.
#
# HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @donatotchilaxaa @donnypangilinan @bellemariano02 HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# Need to be all over this! @alt_J https://t.co/OmvkJDLolh
# ==
# @hbdDONATO_ @fordonutonly_db HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# #eth #nftcommunity #ethereum #crypto #cryptocurrency #tothemoonandback @ Rosebud Beach https://t.co/RLEtkYiCdn
# ==
# @onlyforbondelle HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @DonBelleOFC @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @titasofdonbelle @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @dbsquadofc HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @solelydnbll @donchinnybelle HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @CARABELLE_ @don_bellepm @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# INNR — Marital rape is still legal in India. A court decision could change that: Women's groups have petitioned the Delhi High Court to close a legal ... latest National Family Health Survey, about 30% Indian women aged 18-49 ...
#
# View article... https://t.co/BnKhjLkdWS
# ==
# INNR — Why more women are opting for IT-ITeS courses: There are multiple reasons why women in India are increasingly opting for ... After completing the course, jobs are available in various sectors ...
#
# View article... https://t.co/RM2luILrvk
# ==
# INNR — Refusing to let girls go to school in hijabs is 'horrifying': Malala hits out at Indian leaders: "Indian leaders must stop the marginalisation of Muslim women," Malala Yousafzai, who in 2014 became the youngest-ever Nobel Prize winner for her work… https://t.co/w7LTt5LITx
# ==
# @ceobelinda @steffiyang25 HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @belleantonio @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# Ex Qieensland copper Dutton is very used to verballing people, now hes trying to scare the children, (us) with the old " Reds under the beds" B S! How pathetic! https://t.co/U1DLVR46EF
# ==
# @dbmahalkokayo HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @lebatotz_258 @hourlydb @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @DBNGPLT @DonBelle_1011 HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @Wuaini9 @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @BDonbelle HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @Dhine15068367 @bubblyyhel HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @donbelle_onlyy @dbsquadofc HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @Wuaini9 @donnypangilinan HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# @dearlydonbellez HAPPY 24TH DONNY DAY
#
# #DonnyTurnsTwentyFour
# #BenteKwatroNaSiDONNY
# #DonnyPangilinan
# ==
# INNR — More support needed for women and girls in super typhoon-ravaged Philippines: Her nearest health centre was completely destroyed and she will likely have to travel some 50 kilometres to give birth, she told the UN's sexual and ...
#
# View… https://t.co/flp6HeLEhh
# ==
# INNR — How the Taliban's return has changed Afghan women's lives: The Taliban say they allow women to work as long as they are segregated from men. · The Taliban say all girls are entitled to an education, but the ...
#
# View article... https://t.co/W7ogsR87tJ
# ==
# @bruxxqueta A minha ficou no máximo assim ó, mas não passou disso e depois foi sumindo sozinha, sem anti viral nem nada. https://t.co/5nOHP8DL2H
# ==
# DSS 36 carrier lock on Mars Odyssey
# Frequency: 8.4065GHz
# Signal strength: -144dBm
# IDLE OFF 1 MCD3
# ==
# @translesbian117 @IainSankey @stonewalluk @EHRC What the fuck is a trans lesbian
# A lesbian is a female person who is same sex attracted
# And please don't use the word cis it's offensive and means nothing
# ==
# @mi_native_nutt MMM and Extreme Programming (inspite of bad naming) and other popular sources of wisdom have transformed whole development processes to mostly good direction. Obsession and hype remains J2EE now Kubenetes, XML now JSON, CORBA now REST, Java interpreter now JS (just type unsafe)
# ==
# This week the @NRL brings together one of my favourite games.. The Indig Allstars vs The Moari Allstars. I had the wonderful opportunity a few years back to perform at the game and jersey presentation. Pictured here with some of thr games legends #Respect https://t.co/xhfGLbmYDp
# ==

# %%
df.to_csv('../data/semi_cleaned_AI_tweets.csv')

# %% [markdown]
# # OTHER EDA (NOT IMPORTANT)

# %%
coord = filtered_df['coordinates']
coord = [x for x in coord if x != None]
len(coord)
# Out:
# 4093

# %%
type = filtered_df['type']
type = [x for x in type if x != None]

len(type)
# Out:
# 2

# %%
place_id = filtered_df['place_id']
place_id = [x for x in place_id if x != None]

len(place_id)
# Out:
# 62422

# %%
place_id
# Out:
# ['0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '0ea2a2fc1c54f000',
#  '0118c71c0ed41109',
#  '008402196cea8a83',
#  '0118c71c0ed41109',
#  '01864a8a64df9dc4',
#  '01e8a1a140ccdc5c',
#  '0023f2ab28f1c387',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01e8a1a140ccdc5c',
#  '0118c71c0ed41109',
#  '01864a8a64df9dc4',
#  '01e4b0c84959d430',
#  '01864a8a64df9dc4',
#  '017453ae077eafd3',
#  '004ec16c62325149',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '004ec16c62325149',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '019e32e73d7d3282',
#  '01864a8a64df9dc4',
#  '00a515d443f09983',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01e4b0c84959d430',
#  '0073b76548e5984f',
#  '004ec16c62325149',
#  '004ec16c62325149',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '265b933184e2b88a',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '009b89410157afec',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '019e32e73d7d3282',
#  '0029c1347f5df29b',
#  '0fc3a0cb46d5e000',
#  '019e32e73d7d3282',
#  '004ec16c62325149',
#  '0073b76548e5984f',
#  '6c1477b8ffb6e049',
#  '6c1477b8ffb6e049',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '0118c71c0ed41109',
#  '01e8a1a140ccdc5c',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '01e8a1a140ccdc5c',
#  '01864a8a64df9dc4',
#  '5f7b02e62ae48039',
#  '0118c71c0ed41109',
#  '0118c71c0ed41109',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '00c46e9a5d80721f',
#  '317fcc4b21a604d5',
#  '017453ae077eafd3',
#  '0013cae44d65aff9',
#  '01864a8a64df9dc4',
#  '0029c1347f5df29b',
#  '5f7b02e62ae48039',
#  '0073b76548e5984f',
#  '017453ae077eafd3',
#  '01864a8a64df9dc4',
#  '7e347291be7bbab4',
#  '01552cf31a0d108e',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '12757bbc6654c000',
#  '004ec16c62325149',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  ...]

# %%
filtered_df[(filtered_df['ai_bool'] == 1) & (filtered_df['coordinates'].notnull())]
# Out:
#                          _id                created_at  \
# 4972     1491759637648928768  2022-02-10T13:03:07.000Z
# 318371   1511008845765644290  2022-04-04T15:52:36.000Z
# 380149   1514717036705845252  2022-04-14T21:27:38.000Z
# 739171   1535990896960819200  2022-06-12T14:22:21.000Z
# 745330   1536394754170097664  2022-06-13T17:07:08.000Z
# 745332   1536394785245696000  2022-06-13T17:07:16.000Z
# 787425   1539093299419615234  2022-06-21T03:50:12.000Z
# 945846   1549830466630406144  2022-07-20T18:55:52.000Z
# 980571   1551734835886055426  2022-07-26T01:03:09.000Z
# 1004798  1553150790432333825  2022-07-29T22:49:39.000Z
#
#                           coordinates   type   type          place_id lang  \
# 4972        [77.19102783, 28.5974128]  Point  Point  317fcc4b21a604d5   en
# 318371   [133.96339777, -25.63642933]  Point  Point  40888ddb9f11c18f   en
# 380149    [-73.60404689, 45.51949281]  Point  Point  36775d842cbec509   ko
# 739171   [144.94161989, -37.78821679]  Point  Point  01864a8a64df9dc4   en
# 745330    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 745332    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 787425         [151.20081, -33.88339]  Point  Point  0073b76548e5984f   en
# 945846    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 980571           [151.1036, -33.9104]  Point  Point  0073b76548e5984f   en
# 1004798          [151.1987, -33.8865]  Point  Point  0073b76548e5984f   en
#
#          sentiment                                               text  \
# 4972      0.025641  INNR — AI patient room automation introduced i...
# 318371   -0.130435  Online abuse targeting footballers to be tackl...
# 380149    0.000000  TW :  "귀사의 AI는 안녕하십니까?" NIST, AI 위험 관리 프레임워크 마...
# 739171   -0.043478  Google Engineer On Leave After He Claims AI Pr...
# 745330    0.035714  Spotify is acquiring Sonantic, the AI voice pl...
# 745332   -0.111111  #news #gear #internet #services #microsoft Mic...
# 787425    0.212121  So excited to be back @utsengineeringandit @th...
# 945846    0.050000  Comet Recognized as a Cool Vendor in AI Core T...
# 980571    0.000000  Since my AI experiments, the hackers have made...
# 1004798   0.184211  The future is AI - been creating with @openaid...
#
#                    author_id  ai_bool
# 4972               149585330        1
# 318371   1491316688549253120        1
# 380149             149585330        1
# 739171   1491316688549253120        1
# 745330   1491316688549253120        1
# 745332   1491316688549253120        1
# 787425            1181037025        1
# 945846   1506620226162634758        1
# 980571              18742857        1
# 1004798             21818549        1

# %%
filtered_df
# Out:
#                          _id                created_at coordinates  type  \
# 0        1491845931456774147  2022-02-10T18:46:01.000Z        None  None
# 1        1491846139196452864  2022-02-10T18:46:51.000Z        None  None
# 2        1491817025433489409  2022-02-10T16:51:10.000Z        None  None
# 3        1491844343379992579  2022-02-10T18:39:43.000Z        None  None
# 4        1491814800212611079  2022-02-10T16:42:19.000Z        None  None
# ...                      ...                       ...         ...   ...
# 1074884  1557516967275528193  2022-08-10T23:59:16.000Z        None  None
# 1074885  1557517000686968832  2022-08-10T23:59:24.000Z        None  None
# 1074886  1557517101694611457  2022-08-10T23:59:48.000Z        None  None
# 1074887  1557517147898781701  2022-08-10T23:59:59.000Z        None  None
# 1074888  1557513412393185280  2022-08-10T23:45:09.000Z        None  None
#
#          type          place_id lang  sentiment  \
# 0        None              None   en   0.020408
# 1        None              None   en   0.020408
# 2        None              None   en   0.020833
# 3        None              None   en   0.020408
# 4        None              None   en   0.020833
# ...       ...               ...  ...        ...
# 1074884  None              None   en   0.000000
# 1074885  None  004ec16c62325149   en  -0.162791
# 1074886  None              None   en   0.000000
# 1074887  None              None   en   0.120000
# 1074888  None              None   en   0.000000
#
#                                                       text           author_id
# 0        @Real_DrugTalk DL Down3r´s hit inspirational s...            62407961
# 1        @Real_DrugTalk DL Down3r´s hit inspirational s...            62407961
# 2        @slavetothehat DL Down3r´s hit inspirational s...            62407961
# 3        @jots_8 DL Down3r´s hit inspirational song " S...            62407961
# 4        @badwool9 DL Down3r´s hit inspirational song "...            62407961
# ...                                                    ...                 ...
# 1074884  🇦🇺👏 A great day for the Aussies at the #Canadi...            43806353
# 1074885  I'm listening to the  "eDNA monitoring; 'teleh...  876592795963736064
# 1074886  GBP/USD\nTARGET LEVEL 1.2233\nSL: (B) 1.2199 4...          1115918534
# 1074887  AI tech allows businesses to gather and utilis...           223309438
# 1074888  @jhgates1 @benmooreau @ncdave4life @agentsinac...          3316708940
#
# [1074889 rows x 10 columns]

# %%
from pyspark.sql.functions import min, max

# assuming your data is stored in a Spark DataFrame called 'df'
min_datetime = spark_json.agg(min("doc.data.created_at")).collect()[0][0]
max_datetime = spark_json.agg(max("doc.data.created_at")).collect()[0][0]

print("Minimum datetime:", min_datetime)
print("Maximum datetime:", max_datetime)
# Out:
# [Stage 7:======================================================>(469 + 2) / 471]
# Minimum datetime: 2022-02-10T00:00:00.000Z
# Maximum datetime: 2022-08-10T23:59:59.000Z

# %%
from pyspark.sql.functions import count, col

n_geo_rows = spark_json.select(count(col('doc.data.geo')).alias('count')).collect()[0]['count']

# %%
n_geo_rows
# Out:
# 52396417
# [Stage 13:==============>                                       (128 + 8) / 471]
