# %% [markdown]
# # R_2 Through EDA of 65 GB tweets (on Politics)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("COMP90024_A2_EDA")
    .config("spark.sql.repl.eagerEval.enabled", True)
    .config("spark.sql.parquet.cacheMetadata", "true")
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/23 17:06:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read In Original
spark_json = spark.read.json('../data/raw/BigTwitterFile/twitter-huge.json')

# %%
# Observe Schema
spark_json.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- doc: struct (nullable = true)
#  |    |-- _id: string (nullable = true)
#  |    |-- _rev: string (nullable = true)
#  |    |-- data: struct (nullable = true)
#  |    |    |-- author_id: string (nullable = true)
#  |    |    |-- context_annotations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- domain: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- entity: struct (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- conversation_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- entities: struct (nullable = true)
#  |    |    |    |-- annotations: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- normalized_text: string (nullable = true)
#  |    |    |    |    |    |-- probability: double (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- cashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- tag: string (nullable = true)
#  |    |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- tag: string (nullable = true)
#  |    |    |    |-- mentions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- username: string (nullable = true)
#  |    |    |    |-- urls: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- media_key: string (nullable = true)
#  |    |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |    |-- status: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- unwound_url: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: struct (nullable = true)
#  |    |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- place_id: string (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- public_metrics: struct (nullable = true)
#  |    |    |    |-- like_count: long (nullable = true)
#  |    |    |    |-- quote_count: long (nullable = true)
#  |    |    |    |-- reply_count: long (nullable = true)
#  |    |    |    |-- retweet_count: long (nullable = true)
#  |    |    |-- sentiment: double (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- withheld: struct (nullable = true)
#  |    |    |    |-- copyright: boolean (nullable = true)
#  |    |    |    |-- country_codes: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- includes: string (nullable = true)
#  |    |-- matching_rules: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- tag: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- key: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- value: struct (nullable = true)
#  |    |-- tags: string (nullable = true)
#  |    |-- tokens: string (nullable = true)

# %% [markdown]
# ### Extract Key Columns

# %%
# important features to extract out of the original dataframe
out_df = spark_json.select('doc._id', 'doc.data.created_at', 'doc.data.geo.coordinates.coordinates', 
                  'doc.data.geo.coordinates.type', 'doc.includes', 
                  'doc.data.geo.place_id', 'doc.data.lang', 'doc.data.sentiment', 'doc.data.text', 
                  'doc.data.author_id')

# %% [markdown]
# ### Missing Geolocation

# %%
# observe missing values in 'includes' (geolocation)


from pyspark.sql.functions import col, sum

def count_missing_values(df, column_name):
    # Filter the DataFrame to select rows where the column is null
    filtered_df = df.filter(col(column_name).isNull())
    
    # Use the `sum()` function to count the number of rows with null values
    count = filtered_df.select(sum(col(column_name).isNull().cast("int"))).collect()[0][0]
    
    return count

missing_count = count_missing_values(out_df, "includes")

# %%
missing_count
# Out:
# 49300230

# %%
out_df.count()
# Out:
# 52533743

# %%
52533743 - 49300230
# Out:
# 3233513

# %% [markdown]
# ### Extract Tweets containing AI Keywords

# %%
import pandas as pd
words_df = pd.read_excel('../data/raw/Keywords/Voting Keyword.xlsx')

words = list(words_df['keywords'])
words
# Out:
# ['accountab',
#  'advoca',
#  'affirmative action',
#  'agenda setting',
#  'aspiration',
#  'asylum seeker',
#  'bureaucra',
#  'business',
#  'citizen',
#  'class',
#  'colon',
#  'committee',
#  'communit',
#  'conservati',
#  'constitution',
#  'convention',
#  'corrupt',
#  'crisis',
#  'cultur',
#  'culture wars',
#  'federalism',
#  'democracy',
#  'differen',
#  'discourse',
#  'economic rationalis',
#  'egalitarian',
#  'elit',
#  'environment',
#  'equal',
#  'ethic',
#  'ethinic',
#  'executive',
#  'famili',
#  'feminis',
#  'free',
#  'gender',
#  'globalis',
#  'green',
#  'identity',
#  'ideolog',
#  'indigenous',
#  'individual',
#  'interest group',
#  'international relations',
#  'internet',
#  'judicia',
#  'law',
#  'leader',
#  'liberal',
#  'magnagerialism',
#  'mandate',
#  'media',
#  'ministerialadvisers',
#  'minist ',
#  'multicultural',
#  'national identity',
#  'national identity',
#  'obligation',
#  'others',
#  'otherness',
#  'parliament',
#  'participation',
#  'party',
#  'parties',
#  'polic',
#  'political socialisation',
#  'populism',
#  'post-modern',
#  'power',
#  'protest',
#  'public',
#  'public and private',
#  'public opinion',
#  'public sector',
#  'race',
#  'radical',
#  'religion',
#  'represent',
#  'republic',
#  'responsib',
#  'rights',
#  'secularis',
#  'self-determination',
#  'separation of powers',
#  'sexual',
#  'social capital',
#  'fedderalism',
#  'social democratic',
#  'social democrats',
#  'social movement',
#  'scialism',
#  'terroris',
#  'think tank',
#  'third sector',
#  'trade',
#  'tradition',
#  'treat',
#  'union',
#  'utilitarian',
#  'value',
#  'vot',
#  'federalism',
#  'welfare',
#  'westminister']

# %%
# Only get tweets that contain AI related keywords

from pyspark.sql.functions import col

# Assume 'df' is your DataFrame with a string typed column named 'text'
filter_cond = col('doc.data.text').contains(words[0])  # initial filter condition

for i in range(1, len(words)):
    filter_cond = filter_cond | col('text').contains(words[i])  # add each snippet to the filter condition using the & operator

filtered_df = out_df.filter(filter_cond)  # apply the filter condition to the DataFrame

result_df = filtered_df.filter(col("doc.includes").isNotNull())

# %%
result_df.count()
# Out:
# 319631

# %%
# convert to Pandas df
df = result_df.select("*").toPandas()

# %%
df
# Out:
#                         _id                created_at coordinates  type  \
# 0       1491795863018274816  2022-02-10T15:27:04.000Z        None  None
# 1       1491725195375439877  2022-02-10T10:46:16.000Z        None  None
# 2       1491648779082100739  2022-02-10T05:42:37.000Z        None  None
# 3       1491626908106190848  2022-02-10T04:15:42.000Z        None  None
# 4       1491588166888742912  2022-02-10T01:41:46.000Z        None  None
# ...                     ...                       ...         ...   ...
# 319626  1557514633623191553  2022-08-10T23:50:00.000Z        None  None
# 319627  1557515011781640193  2022-08-10T23:51:30.000Z        None  None
# 319628  1557515835237072896  2022-08-10T23:54:47.000Z        None  None
# 319629  1557515963662077953  2022-08-10T23:55:17.000Z        None  None
# 319630  1557516252821995521  2022-08-10T23:56:26.000Z        None  None
#
#                                                  includes          place_id  \
# 0       {"places":[{"full_name":"Brisbane, Queensland"...  004ec16c62325149
# 1       {"places":[{"full_name":"Brisbane, Queensland"...  004ec16c62325149
# 2       {"places":[{"full_name":"Sydney, New South Wal...  0073b76548e5984f
# 3       {"places":[{"full_name":"Melbourne, Victoria",...  01864a8a64df9dc4
# 4       {"places":[{"full_name":"Melbourne, Victoria",...  01864a8a64df9dc4
# ...                                                   ...               ...
# 319626  {"places":[{"full_name":"Brisbane, Queensland"...  004ec16c62325149
# 319627  {"places":[{"full_name":"Laidley, Queensland",...  00397523196f3174
# 319628  {"places":[{"full_name":"Plenary Hall","geo":{...  07d9e72979884000
# 319629  {"places":[{"full_name":"Brisbane, Queensland"...  004ec16c62325149
# 319630  {"places":[{"full_name":"International Convent...  1198033224d41007
#
#        lang  sentiment                                               text  \
# 0        en  -0.142857  @IMmadashellandi @HeshmatAlavi Israel is a dem...
# 1        en  -0.200000  @stilllukebowden More power to Barbara, Sue an...
# 2        en  -0.015152  @Dr_eVal @Sg3912 @parsleysmum @ardentgreeneyes...
# 3        en   0.333333  @sammyjcomedian @NikkiKlopfer Another reclaime...
# 4        en   0.000000  @MattGurchenko @MrInbetween1 @Garyandthegoat1 ...
# ...     ...        ...                                                ...
# 319626   en  -0.023810  Trump Attorney wasn’t allowed presence when KG...
# 319627   en   0.250000        Mod parties be like https://t.co/jm21gF9qIy
# 319628   en   0.051282  "Teacher's need to start where they're comfort...
# 319629   en  -0.037037  Laid back  sleeping ordinary undecided conserv...
# 319630   en   0.388889  What an amazing start to the #CAA #womeninlead...
#
#                   author_id
# 0                4516171573
# 1                 177543302
# 2        987281520099344384
# 3                 418231895
# 4       1466177366506549251
# ...                     ...
# 319626  1511175941846102021
# 319627            803641382
# 319628           1074293586
# 319629  1511175941846102021
# 319630   747013936931700736
#
# [319631 rows x 10 columns]

# %%
len(df)

# %%
# number of 'real AI related' tweets and has useable geolocation
len(df[(~df['includes'].isnull())])
# Out:
# 49952

# %%
# observes some of these real AI related tweet

i = 0
for txt in df[(~df['includes'].isnull())]['text']:
    print(txt)
    print('==')
    i += 1

    if i == 200:
        break

# HOWEVER, DOESN'T SEEM TO HAVE ACTUALLY MATCHED
# Out:
# @IMmadashellandi @HeshmatAlavi Israel is a democracy and not a dictatorship ruled by fanatics that threatens death to America and Israel! Crawl out of your cave and see light!
# ==
# @stilllukebowden More power to Barbara, Sue and Sarah I say!
# ==
# @Dr_eVal @Sg3912 @parsleysmum @ardentgreeneyes @AlanSla90124663 @HHazcat @Freeds @catmum1932 @MariaPulk @kenobe_wan @denvor18 @Nacho87329549 @Merlin80643296 @starbuckssue @Leonlovescats @tiggy_catt247 @MarisaBerlinge1 @3phibotticelli @LMEVegetarian @GeorgeandMildr4 @JLHerms @cat_fender @EdibleCatsClub @maureenelis @LittleTess3 @creative54 @azzurro_azzurro @NeddlePeddle @TriciaCaputo @walphieplopflee @JenniferBMorri2 @Margare72877928 @MirMGreg @lolamatt47 @MistyKitty3 @NatsRallyCat @Gabrielle_Hope1 @NatalieRobins7 @TheVicarageCat @Wxgirl169 @linda_austin1 @_mongoose @Mrs_J_Bananas @A_affirmations @Meow_Factor @PussycatNaughty @MelvinJ75085444 @AndSalume No poor Etty !!!. Max is fine !
# ==
# @sammyjcomedian @NikkiKlopfer Another reclaimed table. Thanks @sammyjcomedian for helping us keep carbon locked away in lovely furniture https://t.co/vFzWPjKPit
# ==
# @MattGurchenko @MrInbetween1 @Garyandthegoat1 @Top_Shelf100 @Adrian_Beaky @LaborBob @aunty_rhirhi @aunty_rheerhee @Joejoe060978 @Dave43330443 @GotziDel @bozowasher @NitmilukMan @aunty_rheenie Or any info about the 9 businesses he’s in the board at or his 6-7 figure salary per year https://t.co/zJCJ6tnRHd
# ==
# @MattGurchenko @Dirtbox5 @MrInbetween1 @Garyandthegoat1 @Top_Shelf100 @Adrian_Beaky @LaborBob @aunty_rhirhi @aunty_rheerhee @Joejoe060978 @Dave43330443 @GotziDel @bozowasher @NitmilukMan @aunty_rheenie I was 1 of the people who reported him. And @TwitterSupport sent me the confirmation about locking his account. There was a 7 day difference between tweets from his account.
# ==
# @MattGurchenko @MrInbetween1 @plehsdeennoraA @BuggeringBeggar @Dirtbox5 @freddie4ski @Garyandthegoat1 @Top_Shelf100 @Adrian_Beaky @LaborBob @aunty_rhirhi @aunty_rheerhee @Joejoe060978 @Dave43330443 @GotziDel @bozowasher @NitmilukMan @aunty_rheenie @TwitterSupport @TerraceDamo Supposedly Slav is coming down for the weekend for a Gay Music Festival https://t.co/2g20aVYGSn
# ==
# @MattGurchenko @MrInbetween1 @plehsdeennoraA @BuggeringBeggar @Dirtbox5 @freddie4ski @Garyandthegoat1 @Top_Shelf100 @Adrian_Beaky @LaborBob @aunty_rhirhi @aunty_rheerhee @Joejoe060978 @Dave43330443 @GotziDel @bozowasher @NitmilukMan @aunty_rheenie @TwitterSupport @TerraceDamo Well the Festival is in Werribee, where @LaborBob lives.
# Also, if you have evidence of corruption within the government you're better off reporting it to the authorities rather that random twitter uses. This just makes you sound like a 🤪 troll conspiracy theorist.
# ==
# @stephanos3867 @Sarah_Alice_X What truth is that champ? You repeat the accusation of corruption but you don't appear to be interested in reporting it to the authorities. Have you actually got anything or are you just making stuff up?
# ==
# @stephanos3867 @Sarah_Alice_X 😂 Righto, so you've got nothing but rambling. If you've got proof of corruption it's not up to me to believe it or not, it's up to the authorities who will investigate it.
# ==
# @Sarah_Alice_X @stephanos3867 OMG! This just proves that the govt is corrupt and the system put in place to police corruption is corrupt &amp; tyranny &amp; sky falling &amp; stuff...... 🤣🤣🤣🤣
# ==
# @Kon__K @EarlWhite @ScottMorrisonMP lock up refugees for many years . How can he has the balls to criticise China tr treatment of minorities 。@LindaBurneyMP @Sophiecotsis1 @mswlabr #auspol
# ==
# @CyuMr @ArtistAJ17 @shannonrwatts @joerogan @madflavor Virtue signalling? Fuck off with that rape apologist bullshit. Nice fallacious argument from popularity you did there, by the way. Admitting that you sexually assaulted anyone and laughing about it is never funny. They're assholes, like the ppl who find this funny or defend it.
# ==
# @CyuMr @peneloperocks @ArtistAJ17 @shannonrwatts @joerogan @madflavor Fucking hell... When did admitting to sexually assault become "outrageous &amp; controversial". Who gives a fuck if it makes any asshole laugh. It's never funny and it's not comedy. Laughing at sexual assault and not calling it out = misogynist, Peeter.
# ==
# @imogenhiggins02 @OzraeliAvi What #HumanRights don't gays have? They are free to do whatever they want. Nobody gives a toss.
# ==
# @Committee4Syd @RobStokesMP @antonknilsson Honestly it has become a long running joke to ban #escooters for this long while most other #AU states have legalised them in some way with QLD, ACT, TAS &amp; VIC being the forerunners. This generation will be paved by green tech. #NSWLiberals are preventing the inevitable. 🤦‍♂️ #NSW https://t.co/fXMNyASeFI
# ==
# @BehnamAkhavan @PJCullen100 @Eng_IT_Sydney @Sydney_Science @SydneyNano Looking forwards to sponsor and we have lots of free goodies as well as relevant product information @ServicesVacuum @Kunnykun
# ==
# @Feline_Shady @ladyaimless1 @Frank61pc @pickledog47 @kipstergull @DailyShoebill @FoxyLustyGrover @jackie_french_ Me thinks the lady doth protest to much...🤔
# ==
# @Feline_Shady @kipstergull @ladyaimless1 @Frank61pc @pickledog47 @DailyShoebill @FoxyLustyGrover @jackie_french_ .I've posted a few different marches I've attended, all causes worth a March. Also posted a few different hats.. including my exclusive egg carton hat.. ravishing.. https://t.co/LCp54eSKbs
# ==
# @adventure_ali_ Maybe if they get into power for a couple of terms it would be reintroduced. Would no doubt depress current house prices but the upside is more affordable housing for owner occupiers which has much greater social benefit than looking after investors.
# ==
# @amorgado4 @gu_onc @TouijerKarim @EurUrolOncol @EveraertsW @RenuEapen Thanks Afonso. We did discuss the Brazilian trial in last few mins. Agree huge difference in node yield and pN1 rate, but still no difference in primary endpoint. Taking more modes makes no difference to BCR-free survival in either trial #GUCast
# ==
# @path_ethic Great idea! You can have fun with matching coloured highlighters &amp; call it work 😊
# ==
# @mth00877382 Flawless beauty ❤️❤️❤️
# ==
# @MikeySlezak Thank you Michael for the story on #NuclearFusion. Particularly the diagram demonstrating the difference between splitting/combing     atoms, and there effects
# ==
# @WendyNorthey @songdo101 The women that don’t want to bring this government down are part of the problem - not the solution. That’s why we need every voting aged human with their integrity still intact, to vote for @AlboMP
# ==
# @JaneCaro And welfare recipients for #Robodebt Jane?
#
# …. And these apologies aren’t for little mistakes - all of these things have destroyed lives and/or cost lives ….
#
# …. and all of them sadly, are things sorry simply can’t fix …
#
# #auspol
#
# https://t.co/1AsK53cL1p
# ==
# @supertolerant @HomoLittlest @gerardkelly33 @OhHeyJacob @youcaantkillme Poor Jacob. That tweet didn't age well and now he's blocked everyone. hyper-offended individuals with snowflakey identifiers in their bios really need a moment to please think clearly
# ==
# @IffatHasanRizvi True leader. Risk of mob lynching presented. Good to see a teacher/ professors were actively holding the mob. True heroes stood against the angry mob, it encourage a women to stand up for herself. We all need to stand against the unfairness, tyranny and goodness will flow.
# ==
# @VoloderEdin @unionsaustralia @AustralianLabor - outrageous if true
# ==
# @FrankieDTankie @LivengoodKat @CozomoMedici Always love hearing the reasons why pieces resonate with their collectors! Thanks for supporting this community mate 🙌🏼
# ==
# @keeper_energy In the spiritual  realm, time as we know it does not exist?
#
# Einstein's laws of relativity also states time slows down as objects approach the speed of light.
# ==
# @RodneyCroome @Elias_Jahshan This doesn't seem very "reach out and build bridges" and instead seems like "scapegoating during a time of conflicting human rights" but okay
# ==
# @KelvinMatthew13 @dhanks012 @Waynos67 SO you all need to have Your say ! Be heard
# Otherwise this will continue because the minority are the only ones that vote
# Don't be a bunch of slack arses !!!!
# ==
# @Annofgreenpatio @Donsvess Voted for them right up to the last Federal election. Finding out that Morrison is a Evangelical just after the election made me furious. Then him supporting Clive Palmer in his high court challenges. Turned off a huge number of West Aussies.
# ==
# @Annofgreenpatio @Donsvess Excuse me? Who the hell do you think you are. You sound more like a LNP troll. FU. 🖕
# ==
# @RedJules4 She must to  be embarrassing to belongs to corrupt LNP goverment
# ==
# @RyanWil62993886 @Annofgreenpatio I do know that far right wing conservatives have destroyed what used to be the Liberal Party. People like me have seen it and are extremely p🤬ssed off. All you lot have done is turn people away from the LNP. Just like with what happened to Trump. It's over, finished, done.
# ==
# @SquizzSTK Thanks to both Brittany and Grace for their work yesterday, and today and tomorrow. I know how traumatising it can be to raise abuse in the first place, let alone discuss it publicly, have it politicised or to be disbelieved and discredited. So proud of you both.
# ==
# @OcarinaJones @kenoath58 @Des_Unsociable Mainstream Oz isn't comprised of men frightened that strong women might take away some of the power they think they have over them.
# ==
# @macsween_prue @TamePunk Grace isn't where she is for her good looks &amp; beaming smile.  She is there because she was abused by someone in power.  Focus.  You would probably be bitter &amp; angry as well.  Oh wait, you already are.
# ==
# @ACurrentAffair9 Don’t think the other party is immune to the disrespect and wrong decisions either. You’d be pretty stupid to think otherwise. None are genuinely interested in the Aust. Public, just their own lining of pockets. It’s true !!!! NEVER trust’em.
# ==
# @adamliaw Good taste should be the only law in cookery. That said, if you put pineapple on pizza you are dead to me!
#
# Btw @varungandhi80 surely ur mummy, Maneka Gandhi, has some qualifications when she threatens a #VET on animal welfare matters.
# ==
# @Guaxary @JayMG2205 @SharazDavid I didn't ask for a lesson thanks.
# As a woman and a DV Survivor I still value the meaning behind the sentiment in the phrase "never let her go"
# ==
# @MissLucy_2011 @MareeRosier @TamePunk And a lesson is learnt that may well be the catalyst for change in culture,
# ==
# @dilusionalworld @GloryDaze9 @TamePunk 1 of his tweets is about how beautiful a woman is.
# An objectifier of women and one who has issues with a advocate for child sexual abuse... Makes me wonder what's on his computer.
# ==
# @AngusTaylorMP @LiberalAus @CEFCAus A $5m grant that will never be delivered. Another broken promise. You will all be voted out later this year @ScottMorrisonMP #auspol https://t.co/h3N6i2hicU
# ==
# @60Mins Seriously @60Mins you've sunk this low? Rupert getting worried perhaps,needs to give old mate a boost and  Karl will do a fluff piece so the nufties feel sorry for him. Jenny can't save the #LNPDisgrace. How does MSM get away with this crap!
# ==
# @Toonaciliata @WeAreAllVIPs @60Mins Please remember everyone Peter Costello is Chairman of @Channel9 entertainment and Fairfax newspapers (The Age &amp; SMH).These media outlets are now the official propaganda arms of the Liberal party alongside all of the Murdoch owned media.
# ==
# @christianlexus @oldjoeschmo @60Mins @ScottMorrisonMP @Channel9 has ZERO CREDIBILITY when it comes to politics or the Liberal party. It will only be considered “independent media” when channel 9 &amp; Fairfax media are broken up &amp; Peter Costello, former Liberal deputy to Johnny Howard isn’t chairman.
# ==
# @60Mins This is not journalism, this is pathetic marketing for a failed and religious extremists government mired in corruption and sexual assualt scandals
# ==
# @RupertsConscie1 @Soori82745821 @60Mins Imagine if "our" media were brave enough to demand truth from power. Just imagine.
# ==
# @PeterWallaceAU Same treatment for people who write stupid tweets I’d say!!
# Oh that’s right u can’t treat stupid…
# ==
# @toe_Cutter4 @olliemichals @mark_melbin @AlboMP I agree, in a time where the communities concerns over environmental and ecological policies have grown exponentially the Greens vote is still stuck on 10%.
# ==
# @mark_melbin @LFP58222981 @TheLeft03724569 @DanielAndrewsMP You’re probing! Not the first time you’ve followed this line of questioning! What don’t we like about Dan? I see what’s going on here, your probing probably for a gauge of the public mood for PR research. Clever! I’ll give you that!
# ==
# @TheLeft03724569 @LFP58222981 @mark_melbin @DanielAndrewsMP Probably a PR researcher for Andrews! Probing by provoking to gauge public mood. Again, clever!
# ==
# @katea76 Never and ever to many corrupted all together to destroyed our country
# ==
# @JoshFrydenberg @LiberalAus Deliver failures? Not long until you’re all voted out
#
# @ScottMorrisonMP #auspol https://t.co/LxmKmbR2Xt
# ==
# @DanielAndrewsMP First of all, it is necessary to remind and warn that no religion, no organization, no belief, no ideology, etc., etc., nothing and no right to limit the natural-emotional tendencies of any human being in anywhere  in this world...
# ==
# @DanielAndrewsMP VICTORIANS  are more powerful than everyone thinks.😉
# ==
# @PinkyDink4 @robbieolive1 @Russputin2 No  different shape, look like beef steak.
# ==
# @peppersmithlife Oh but they were helping me, encouraging me to freedom, to be myself, to be in effect liberated.
# ==
# @terrygdmorriss1 @ACUmedia @ZSkrbis Thanks Uncle!
# ==
# @colonelhogans I kinda knew but you articulated it so well. Stay and keep fighting if you can. 🍀
# ==
# @JonathonMomsen @GlennColgan @colonelhogans You're one of the people @colonelhogans is referring to
# ==
# @colonelhogans They were so sure this would be a huge wedge!
# ==
# @georgiedent @RonniSalt Such a hard choice,
# Who to believe?
#  #ScottyThePathologicalLiar @ScottMorrisonMP ...
#  #Dutton's #CrimesAgainstHumanity &amp; #CrimesAgainstChildren party, the ZERO integrity boy, &amp; backstabber central
# Or
# @TamePunk?
#
# #auspol
# #auspoll
# #Australia
#
# Who would u believe @PeterDutton_MP? https://t.co/skElZ9D9rt
# ==
# @classic_sale Man that sucks 🤔😒
# ==
# @WookOfficial Pretty happy with it without it being brilliant, but then it sort of felt like a setup series like Mando S1. Season 2 is where business really picked up, so bobf S1 echoed that for me. Expecting a lot more if there ends up being additional seasons.
# ==
# @ErinInTheMorn @Sputnik_g I'm so envious of people who get something from paracetamol.
# ==
# @PoliBard The others are sitting down with a drink therefore covid can't get you
# ==
# @skipsterW @RacenetTweets @richieplz You can, of course but makes you look like a fool without showing what you can do differently which may be better than what they do. Either put up or 🤐
# ==
# @sandyosullivan Sandy, read " the case of the paisley Snail " this case is seen as the first example of the impact of religion in regard to duty of care   Although occurred in U.K we have in Australia the Westminster System .
# ==
# @democrazymedia Brarti kamu bukan pemimpin
# ==
# @SeverineFrance1 Flawless beauty ❤️❤️❤️
# ==
# @SeverineFrance1 Flawless beauty ❤️❤️❤️
# ==
# @last_jones @conny_page You obviously understand the old testimony is irrelevant to the saviour! Indeed specifically replaced with grace!
# ==
# @last_jones @conny_page Many many parts of the scriptures indeed the gospels is simply “good advice” not law. Grace is faith based, faith changes one’s way of thinking. one’s actions are still failing however salvation exists purely because we cannot be the nature of God. This is hard for many to accept
# ==
# @SolVelasquezA Cuando las boleterias eran en la ventanilla de la tribuna Sur, eso si eran problemas. De la nada aparecía Berrocal por atrás y dejaba sin boletos a media cola.
# ==
# @UncleChilliMan You obviously lack reading comprehension. Looks like you've never owned a business either.
# ==
# @SocialPiranha3 @mugenx86 @theluckylance A victim is someone who becomes harmed by another's actions.
# We have achieved a very high level of vax.
# Denying people the access to jobs and unemployment benefits is to harm them and their families.
# It is no longer warranted to harm them further.
# ==
# @ineffyble Effy no it's too purist to want to protect employees and I think you'll be pleasantly surprised by our decision to vote to pass it anyway when (a) amendments to the shit things fail &amp; (b) we made it easy to pass and become law by already voting for the bad things in the house
# ==
# @ineffyble effy no it's too purist to want to protect employees and i think you'll be pleasantly surprised by our decision to vote in the senate to pass it anyway when (a) amendments to the shit things fail &amp; (b) it will become law when senate amendments fail, &amp; we made it easy to happen ☺️
# ==
# @jabjabforever @SunjahChris @SkyNews Skin colour has nothing to do with it. A video of a large male being cruel to a small pet cat whilst a child watches on is the only issue.I detest racism but I also detest people using race to deflect from the real issue.
# ==
# @khushbuSahu8 @Mangalmay_DGTL Absolutely right
# Judiciary is corrupt
# Sant Shri Asharamji Bapu is innocent
# बापूजी को रिहा करो
# #ReleaseBapuji4OurVote
# ==
# @Boogerbeard1 Yep, one less thing. But don't worry, we'll still have, politics, religion, our favourite msm, music, etc, etc...
# ==
# @Homeoffree61 No. It's the message that counts.
# ==
# @Hannahgrace_tm Love this 💕
# ==
# @gaburnsagain @321jz @8_27J @1Outlaw_ @x4eileen @A9000D @TomAnon @goin_nice @4Mischief @CrushDS6x @cowboy_jms @TheGrayRider @beyond_reasons @SilvermanMark70 @IngloriousBhere @Happygirldeb1 @FastFreddyy @TRCreamer @DonaCoad @smrose29 @CaliGal78 @BB_Scats @45_FT20 @Vet4DJT IFB 100%
# ==
# @JohnnyBSkol @DomClare @Tylerforsure @ZachGelb He's trying to drive up his value
# ==
# @examiner1277 @JohnG_UK @dranthonygustin And of the smaller amounts that genuinely could be classified as  marginal land. Are they truly useless?
#
# Or is that only through the extractive and totally dominant lens of food production? I’d say to wildlife, and the ecosystem itself, they’re not so marginal.
# ==
# @jxs606 @HeatherIsUnsane @PostAshley42 Holy crap… under 6?!? Mine are 10y girl and 2 boys, one almost 8 and the other is 5.
# I guess I don’t remember having so many rights or privileges as a kid… and I knew my privileges were privileges- these monkeys think they’re actually rights.
# Netflix is not a right! 😂
# ==
# @RattusRoger @Metro_Ents The many different names and personalities of his hands…
# ==
# @smruti_rajai Sant Shri Asharamji Bapu is innocent still not getting bail due to corrupt judiciary.
# बापूजी को रिहा करो
# #ReleaseBapuji4OurVote
# ==
# @ReshmaChturvedi @BJP4India @BJP4UP @BJPLive @BJPVinodSonkar @drdineshbjp @BJP4Maharashtra @PMOIndia
# Sant Shri Asharamji Bapu has been jailed via conspiracy. How India can become world leader without Hindu saints ???
# बापूजी को रिहा करो
# #ReleaseBapuji4OurVote
# ==
# @AusIndiMedia Definitely not me! Morrison has played the “Jenny” Card far too often  for this to be just a genuinely nice fireside chat to show that he is human and just like each of us. He’s consistently proven that he doesn’t care about us and only cares about his own power. #LordOfTheLies
# ==
# @ComeGeekSome1 The only thing that helps me is on four legs and follows me everywhere Those big brown eyes melt my heart So playtime walks and treats
# How time flys He is 14 this year &amp; has a heart murmur
# I spend as much time with him as I can Lots of Mummy💗&amp; hugs
# I absolutely LOVE him https://t.co/lHff6TKHgV
# ==
# @dszeligowski @RutheniaRus what about freedom of navigation
# ==
# @ChangaYT Not as big news as make out to you'll need more different tables breaking differently to reearn all our trust back after the worst wrestling game of all time.
# ==
# @poseofpower @MissVerse_ Need to lay down after this ❤️
# ==
# @IanChaplin19 @TownsvilleTom @HUSHABOMB @AdyLady9969 @AlboMP @SenatorWong Cool. So if I don’t take what you say on faith about a party with a history of being shitty on queer issues that’s on me?Albo is playing 4D chess because… he approved a shitty bill that was ever so slightly less shitty? I’m not here in bad faith, show me the mess of dots connect
# ==
# @TraceRemix Here for this!!!
# ==
# @narendramodi Honourable sir I would like to bring to your kind notice the pathetic condition of a reputed nationalise bank like SBI to treat its foreign investors . Once the account is open and your transfer dollars to your Indian account and when your SBI international bank we need to remind
# ==
# @narendramodi Sorry in conversation to my earlier msg about SBI we are treated like a rubbish bin as they can’t send us our bank debit card but wants us to give a Indian address for delivery then how can a customer who is overseas access his debit card or use it international
# ==
# @mjrowland68 It's fairly obvious this Religious bill debate right before the election is a deliberate effort to divide voters
# Straight out of the LNP/ Murdoch playbook...
# Labor know this + are acting to reduce the carnage
# #auspol
# #scomo #ScottyTheCreep
# #alpolitics #ScottyTheCompletePsycho
# ==
# @BelindaJones68 @mjrowland68 It's fairly obvious this Religious bill debate right before the election is a deliberate effort to divide voters
# Straight out of the LNP/ Murdoch playbook...
# Labor know this + are acting to reduce the carnage
# #auspol
# #scomo #ScottyTheCreep
# #alpolitics #ScottyTheCompletePsycho
# ==
# @mjrowland68 Hospitals know that human judgement &amp; technical skills overnight are impaired. Fatigue is like alcohol.
# That's why we avoid surgery after midnight in all except urgent, life-threatening cases.
# Surely parliaments can do better than sit overnight.
# ==
# @amtvmedia It is about to go slow motion. https://t.co/LjhlBYs0MT
# ==
# @craigthomler @AlboMP You have no concept of how this parliament works… if one does NOT have the no’s. One uses tactics… try to think!
# ==
# @craigthomler @AlboMP Wow 10k followers, hope he’s not registered to vote … thinking must be a novelty!
# ==
# @AlboMP @secomb_michael Labor should make it plain to the wider community that the party stands for human rights. Human rights and respecting differences instead of bigotry and division that Morrison’s bill would have created. When are you going to announce an end to indefinite detention of refugees?
# ==
# @giddyupbill @AlboMP @MakeMayoMatter Yes, no one is saying it's a great bill. You're simply making it a game of 'Yes' and 'No' with a morality yardstick against the real-world consequences of passing the law by voting 'no'.
# Would you have preferred the law be passed yesterday &amp; on assent have people suffer?
# ==
# @giddyupbill @AlboMP @MakeMayoMatter Essentially you're doing what most independents are doing.
# Saying, "I'm taking a moral stand and fighting this bill at every stage, but I don't have the numbers, so not much I can do. Look! The big party didn't so anything".
# ==
# @giddyupbill This account by the Guardian is evidence 👇🏼
# "Despite Archer and Zimmerman voting against the government, shortly after 2:30am the speaker Andrew Wallace used his casting vote to break a 62-all tie to thwart Labor’s amendment to the controversial clause."
# ==
# @KVgonewild @gerson008 @craigthomler @AlboMP Only if you follow their how to vote cards, if you do the preferences yourself you decide where the votes go
# ==
# @fransi1803 @AlboMP Labor are just going through the motions to win votes.
# ==
# @AlboMP @MSMWatchdog2013 What about the rest of us?
#
# I am gender fluid, homosexual and disabled.
#
# You treat us as second class citizens in the end, same as those govt religious zealots.
#
# @AdamBandt
# ==
# @BreakfastMonke2 @tinkying @lenyeighton @tazgecko @AlboMP Both parties deserve blame, criticism, and condemnation.
# ==
# @SynapticThread @BaxterPeterba @RebeccaHurst19 @barbpar @AlboMP It started as a untenable law cut and pasted from the US that would never have passed the senate. Labor gave it legitimacy and it remains a dreadful shitful piece of law. You need to look at what this law entails and look at where Labor gets their funding.
# ==
# @zalisteggall @BeachPhilosophy @latingle @MakeMayoMatter @helenhainesindi @AdamBandt @WilkieMP @BridgetArcherMP READ ..Snail on the bottle . This case in 1920 formed the impact of religion on our legal system on Australia ...Treat thy Neighbour. Quote from The Bible
# ==
# @InflatablePlant Yes, thank you for telling a gay man who worked in LGBTQI+ rights advocacy to hate gay people!
# ==
# @scottyisrocky @JStagoll @W1Denbar53 @StrewthQueen @StephenJonesMP Pretty sure Greens MP and some on crossbench also voted against it. So...
# ==
# @kurorobeast @SuperApesClub @SamGroeller @ChadHuckel @liampower93
# ==
# @JoshHargraves2 @SarahOC_MECFS And what a surprise: you're one of the abuser class yourself.
# ==
# @r_nd_rgh Having paid a bit of attention to the evening, night and morning sky consistently for 5-6 years now, it makes so much sense why so many religions follow the timetables of observable patterns in the sun, moon and stars.
# ==
# 23/04/23 18:53:09 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 359495 ms exceeds timeout 120000 ms
# 23/04/23 18:53:09 WARN SparkContext: Killing executors is not supported by current scheduler.

# %%
df.to_csv('../data/semi_cleaned_voting_tweets.csv')

# %%
import pandas as pd
df = pd.read_csv('../data/semi_cleaned_voting_tweets.csv')

# %%
df.loc[0]['includes']
# Out:
# '{"places":[{"full_name":"Brisbane, Queensland","geo":{"type":"Feature","bbox":[152.668522848,-27.767440994,153.31787024,-26.996844991],"properties":{}},"id":"004ec16c62325149"}]}'

# %% [markdown]
# # OTHER EDA (NOT IMPORTANT)

# %%
coord = filtered_df['coordinates']
coord = [x for x in coord if x != None]
len(coord)
# Out:
# 4093

# %%
type = filtered_df['type']
type = [x for x in type if x != None]

len(type)
# Out:
# 2

# %%
place_id = filtered_df['place_id']
place_id = [x for x in place_id if x != None]

len(place_id)
# Out:
# 62422

# %%
place_id
# Out:
# ['0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '0ea2a2fc1c54f000',
#  '0118c71c0ed41109',
#  '008402196cea8a83',
#  '0118c71c0ed41109',
#  '01864a8a64df9dc4',
#  '01e8a1a140ccdc5c',
#  '0023f2ab28f1c387',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01e8a1a140ccdc5c',
#  '0118c71c0ed41109',
#  '01864a8a64df9dc4',
#  '01e4b0c84959d430',
#  '01864a8a64df9dc4',
#  '017453ae077eafd3',
#  '004ec16c62325149',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '017453ae077eafd3',
#  '004ec16c62325149',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '019e32e73d7d3282',
#  '01864a8a64df9dc4',
#  '00a515d443f09983',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '01e4b0c84959d430',
#  '0073b76548e5984f',
#  '004ec16c62325149',
#  '004ec16c62325149',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '265b933184e2b88a',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '009b89410157afec',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  '019e32e73d7d3282',
#  '0029c1347f5df29b',
#  '0fc3a0cb46d5e000',
#  '019e32e73d7d3282',
#  '004ec16c62325149',
#  '0073b76548e5984f',
#  '6c1477b8ffb6e049',
#  '6c1477b8ffb6e049',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '017453ae077eafd3',
#  '013236020befec85',
#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  

#  '01864a8a64df9dc4',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '0118c71c0ed41109',
#  '01e8a1a140ccdc5c',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '01e8a1a140ccdc5c',
#  '01864a8a64df9dc4',
#  '5f7b02e62ae48039',
#  '0118c71c0ed41109',
#  '0118c71c0ed41109',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '00c46e9a5d80721f',
#  '317fcc4b21a604d5',
#  '017453ae077eafd3',
#  '0013cae44d65aff9',
#  '01864a8a64df9dc4',
#  '0029c1347f5df29b',
#  '5f7b02e62ae48039',
#  '0073b76548e5984f',
#  '017453ae077eafd3',
#  '01864a8a64df9dc4',
#  '7e347291be7bbab4',
#  '01552cf31a0d108e',
#  '01864a8a64df9dc4',
#  '0073b76548e5984f',
#  '12757bbc6654c000',
#  '004ec16c62325149',
#  '0073b76548e5984f',
#  '0073b76548e5984f',
#  '01864a8a64df9dc4',
#  ...]

# %%
filtered_df[(filtered_df['ai_bool'] == 1) & (filtered_df['coordinates'].notnull())]
# Out:
#                          _id                created_at  \
# 4972     1491759637648928768  2022-02-10T13:03:07.000Z
# 318371   1511008845765644290  2022-04-04T15:52:36.000Z
# 380149   1514717036705845252  2022-04-14T21:27:38.000Z
# 739171   1535990896960819200  2022-06-12T14:22:21.000Z
# 745330   1536394754170097664  2022-06-13T17:07:08.000Z
# 745332   1536394785245696000  2022-06-13T17:07:16.000Z
# 787425   1539093299419615234  2022-06-21T03:50:12.000Z
# 945846   1549830466630406144  2022-07-20T18:55:52.000Z
# 980571   1551734835886055426  2022-07-26T01:03:09.000Z
# 1004798  1553150790432333825  2022-07-29T22:49:39.000Z
#
#                           coordinates   type   type          place_id lang  \
# 4972        [77.19102783, 28.5974128]  Point  Point  317fcc4b21a604d5   en
# 318371   [133.96339777, -25.63642933]  Point  Point  40888ddb9f11c18f   en
# 380149    [-73.60404689, 45.51949281]  Point  Point  36775d842cbec509   ko
# 739171   [144.94161989, -37.78821679]  Point  Point  01864a8a64df9dc4   en
# 745330    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 745332    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 787425         [151.20081, -33.88339]  Point  Point  0073b76548e5984f   en
# 945846    [144.95697498, -37.7813477]  Point  Point  01864a8a64df9dc4   en
# 980571           [151.1036, -33.9104]  Point  Point  0073b76548e5984f   en
# 1004798          [151.1987, -33.8865]  Point  Point  0073b76548e5984f   en
#
#          sentiment                                               text  \
# 4972      0.025641  INNR — AI patient room automation introduced i...
# 318371   -0.130435  Online abuse targeting footballers to be tackl...
# 380149    0.000000  TW :  "귀사의 AI는 안녕하십니까?" NIST, AI 위험 관리 프레임워크 마...
# 739171   -0.043478  Google Engineer On Leave After He Claims AI Pr...
# 745330    0.035714  Spotify is acquiring Sonantic, the AI voice pl...
# 745332   -0.111111  #news #gear #internet #services #microsoft Mic...
# 787425    0.212121  So excited to be back @utsengineeringandit @th...
# 945846    0.050000  Comet Recognized as a Cool Vendor in AI Core T...
# 980571    0.000000  Since my AI experiments, the hackers have made...
# 1004798   0.184211  The future is AI - been creating with @openaid...
#
#                    author_id  ai_bool
# 4972               149585330        1
# 318371   1491316688549253120        1
# 380149             149585330        1
# 739171   1491316688549253120        1
# 745330   1491316688549253120        1
# 745332   1491316688549253120        1
# 787425            1181037025        1
# 945846   1506620226162634758        1
# 980571              18742857        1
# 1004798             21818549        1

# %%
filtered_df
# Out:
#                          _id                created_at coordinates  type  \
# 0        1491845931456774147  2022-02-10T18:46:01.000Z        None  None
# 1        1491846139196452864  2022-02-10T18:46:51.000Z        None  None
# 2        1491817025433489409  2022-02-10T16:51:10.000Z        None  None
# 3        1491844343379992579  2022-02-10T18:39:43.000Z        None  None
# 4        1491814800212611079  2022-02-10T16:42:19.000Z        None  None
# ...                      ...                       ...         ...   ...
# 1074884  1557516967275528193  2022-08-10T23:59:16.000Z        None  None
# 1074885  1557517000686968832  2022-08-10T23:59:24.000Z        None  None
# 1074886  1557517101694611457  2022-08-10T23:59:48.000Z        None  None
# 1074887  1557517147898781701  2022-08-10T23:59:59.000Z        None  None
# 1074888  1557513412393185280  2022-08-10T23:45:09.000Z        None  None
#
#          type          place_id lang  sentiment  \
# 0        None              None   en   0.020408
# 1        None              None   en   0.020408
# 2        None              None   en   0.020833
# 3        None              None   en   0.020408
# 4        None              None   en   0.020833
# ...       ...               ...  ...        ...
# 1074884  None              None   en   0.000000
# 1074885  None  004ec16c62325149   en  -0.162791
# 1074886  None              None   en   0.000000
# 1074887  None              None   en   0.120000
# 1074888  None              None   en   0.000000
#
#                                                       text           author_id
# 0        @Real_DrugTalk DL Down3r´s hit inspirational s...            62407961
# 1        @Real_DrugTalk DL Down3r´s hit inspirational s...            62407961
# 2        @slavetothehat DL Down3r´s hit inspirational s...            62407961
# 3        @jots_8 DL Down3r´s hit inspirational song " S...            62407961
# 4        @badwool9 DL Down3r´s hit inspirational song "...            62407961
# ...                                                    ...                 ...
# 1074884  🇦🇺👏 A great day for the Aussies at the #Canadi...            43806353
# 1074885  I'm listening to the  "eDNA monitoring; 'teleh...  876592795963736064
# 1074886  GBP/USD\nTARGET LEVEL 1.2233\nSL: (B) 1.2199 4...          1115918534
# 1074887  AI tech allows businesses to gather and utilis...           223309438
# 1074888  @jhgates1 @benmooreau @ncdave4life @agentsinac...          3316708940
#
# [1074889 rows x 10 columns]

# %%
from pyspark.sql.functions import min, max

# assuming your data is stored in a Spark DataFrame called 'df'
min_datetime = spark_json.agg(min("doc.data.created_at")).collect()[0][0]
max_datetime = spark_json.agg(max("doc.data.created_at")).collect()[0][0]

print("Minimum datetime:", min_datetime)
print("Maximum datetime:", max_datetime)
# Out:
# [Stage 7:======================================================>(469 + 2) / 471]
# Minimum datetime: 2022-02-10T00:00:00.000Z
# Maximum datetime: 2022-08-10T23:59:59.000Z

# %%
from pyspark.sql.functions import count, col

n_geo_rows = spark_json.select(count(col('doc.data.geo')).alias('count')).collect()[0]['count']

# %%
n_geo_rows
# Out:
# 52396417
# [Stage 13:==============>                                       (128 + 8) / 471]
