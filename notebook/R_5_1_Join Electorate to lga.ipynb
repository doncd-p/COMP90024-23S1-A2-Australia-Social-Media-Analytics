# %% [markdown]
# # R_5.1 Join Electorate to lga
# - so we can take intersection and proportionate data

# %% [markdown]
# ### Import and preprocess data into correct geographical form

# %%
import geopandas as gpd
from pyproj import CRS
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
gdf = gpd.read_file('../data/raw/Geography/2021_ELB_region.shp')

# %%
# correct geocode for Australia
new_crs = CRS.from_epsg(4283)  

# Reproject the GeoDataFrame to the new CRS
gdf = gdf.to_crs(new_crs)

# %%
# remove redundant columns
gdf = gdf[['E_div_numb', 'Elect_div', 'Area_SqKm', 'geometry']]
gdf
# Out:
#      E_div_numb  Elect_div   Area_SqKm  \
# 0             1      Banks       49.47
# 1             2     Barton       39.65
# 2             3  Bennelong       58.76
# 3             4    Berowra      741.64
# 4             5   Blaxland       61.16
# ..          ...        ...         ...
# 146          11   O'Connor  1126936.75
# 147          12     Pearce      782.75
# 148          13      Perth       79.92
# 149          14       Swan      150.89
# 150          15    Tangney      101.97
#
#                                               geometry
# 0    POLYGON Z ((151.12967 -33.97363 0.00000, 151.1...
# 1    POLYGON Z ((151.17424 -33.92497 0.00000, 151.1...
# 2    POLYGON Z ((151.15908 -33.79871 0.00000, 151.1...
# 3    POLYGON Z ((151.28480 -33.57221 0.00000, 151.2...
# 4    POLYGON Z ((151.04441 -33.84205 0.00000, 151.0...
# ..                                                 ...
# 146  MULTIPOLYGON Z (((129.00205 -30.76778 0.00000,...
# 147  POLYGON Z ((115.98284 -31.74189 0.00000, 115.9...
# 148  POLYGON Z ((115.96432 -31.88769 0.00000, 115.9...
# 149  POLYGON Z ((116.04102 -31.98350 0.00000, 116.0...
# 150  POLYGON Z ((115.95162 -32.08277 0.00000, 115.9...
#
# [151 rows x 4 columns]

# %%
gdf['own_calculated_area'] = gdf.geometry.area
# Out:
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_72249/3467881995.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['own_calculated_area'] = gdf.geometry.area

# %%
# remove redundant columns
gdf2 = gpd.read_file('../data/raw/Geography/abs_regional_population_lga_2001_2021-.shp')
# erp is estimated population population

# %%
gdf2.columns
# Out:
# Index(['births_200', 'natural_i1', 'births_202', 'births_203', 'state_nam4',
#        'net_inter5', 'deaths_206', 'internal_7', 'natural_i8', 'overseas_9',
#        'natural_10', 'overseas11', 'lga_name12', 'internal13', 'overseas14',
#        'deaths_215', 'internal16', 'lga_code17', 'net_over18', 'internal19',
#        'deaths_220', 'erp_2017', 'erp_2018', 'erp_2019', 'net_inte21',
#        'erp_2021', 'erp_2020', 'erp_chan22', 'net_over23', 'overseas24',
#        'net_inte25', 'overseas26', 'net_over27', 'overseas28', 'area_km2',
#        'net_inte29', 'overseas30', 'erp_2008', 'erp_2009', 'erp_2006',
#        'erp_2007', 'net_inte31', 'births_232', 'erp_2012', 'erp_2011',
#        'erp_2010', 'internal33', 'erp_2016', 'deaths_234', 'erp_2015',
#        'erp_2014', 'erp_2013', 'internal35', 'erp_chan36', 'internal37',
#        'overseas38', 'overseas39', 'internal40', 'deaths_241', 'state_co42',
#        'natural_43', 'pop_dens44', 'net_over45', 'primaryi46', 'overseas47',
#        'erp_2001', 'erp_2003', 'erp_2002', 'erp_2005', 'internal48',
#        'erp_2004', 'internal49', 'net_over50', 'natural_51', 'births_252',
#        'geometry'],
#       dtype='object')

# %%
gdf2 = gdf2[['lga_name12', 'lga_code17', 'area_km2', 'geometry']]

# %%
gdf2
# Out:
#                        lga_name12 lga_code17      area_km2  \
# 0                          Albury      10050    305.638611
# 1                       Blacktown      10750    238.847107
# 2                      Shoalhaven      16950   4567.201172
# 3                       Singleton      17000   4892.716797
# 4           Snowy Monaro Regional      17040  15164.790039
# ..                            ...        ...           ...
# 542  Queanbeyan-Palerang Regional      16490   5319.007324
# 543                      Randwick      16550     36.331001
# 544               Richmond Valley      16610   3047.374756
# 545                          Ryde      16700     40.474602
# 546                  Shellharbour      16900    147.420807
#
#                                               geometry
# 0    POLYGON ((146.86565 -36.07293, 146.86511 -36.0...
# 1    POLYGON ((150.87088 -33.82386, 150.87077 -33.8...
# 2    MULTIPOLYGON (((150.33445 -35.63152, 150.33444...
# 3    POLYGON ((150.79493 -32.50099, 150.79925 -32.5...
# 4    POLYGON ((149.09592 -35.81761, 149.09592 -35.8...
# ..                                                 ...
# 542  POLYGON ((150.03807 -35.37024, 150.03844 -35.3...
# 543  MULTIPOLYGON (((151.26545 -33.92631, 151.26533...
# 544  POLYGON ((152.74500 -28.99288, 152.74520 -28.9...
# 545  POLYGON ((151.11587 -33.83722, 151.11576 -33.8...
# 546  MULTIPOLYGON (((150.87680 -34.54498, 150.87642...
#
# [547 rows x 4 columns]

# %%
# Reproject the GeoDataFrame to the new CRS
gdf2 = gdf2.to_crs(new_crs)

# %%
# calculate the intersection of the polygons
intersection = gpd.overlay(gdf, gdf2, how='intersection')
# Out:
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_72249/589083907.py:2: UserWarning: `keep_geom_type=True` in overlay resulted in 61031 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   intersection = gpd.overlay(gdf, gdf2, how='intersection')

# %%
new_crs = CRS.from_epsg(4283)  # Example: WGS 84

# Reproject the GeoDataFrame to the new CRS
intersection = intersection.to_crs(new_crs)

# %%
# find the intersecting area
intersection['intersection_area'] = intersection.geometry.area
# Out:
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_72249/2089829042.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['intersection_area'] = intersection.geometry.area

# %%
# find the percentage of the overlapped area within the electorate
intersection['percentage_overlap'] = intersection['intersection_area']/intersection['own_calculated_area']

# %%
# EDA to see number of meaningful overlap (i.e. consider any below 0.01 as rounding errors, and equally above 0.99)
len(intersection[(intersection['percentage_overlap'] < 0.99) & (intersection['percentage_overlap'] >0.01)])
# Out:
#       E_div_numb Elect_div   Area_SqKm  own_calculated_area  \
# 1              9      Cook       64.40             0.009156
# 3             19    Hughes      358.87             0.036007
# 6              1     Banks       49.47             0.005169
# 7              2    Barton       39.65             0.003861
# 8              5  Blaxland       61.16             0.005958
# ...          ...       ...         ...                  ...
# 1388          11  O'Connor  1126936.75           104.523579
# 1394          11  O'Connor  1126936.75           104.523579
# 1403          11  O'Connor  1126936.75           104.523579
# 1421          14      Swan      150.89             0.015257
# 1423          14      Swan      150.89             0.015257
#
#                 lga_name12 lga_code17      area_km2  \
# 1         Sutherland Shire      17150    333.580597
# 3         Sutherland Shire      17150    333.580597
# 6     Canterbury-Bankstown      11570    110.237396
# 7     Canterbury-Bankstown      11570    110.237396
# 8     Canterbury-Bankstown      11570    110.237396
# ...                    ...        ...           ...
# 1388            Coolgardie      51960  30297.697266
# 1394             Esperance      53290  44797.546875
# 1403            Lake Grace      54900  11886.319336
# 1421           South Perth      57840     19.811399
# 1423         Victoria Park      58510     17.939600
#
#                                                geometry  intersection_area  \
# 1     POLYGON Z ((151.23193 -34.01674 0.00000, 151.2...           0.005154
# 3     MULTIPOLYGON Z (((151.17127 -34.08262 0.00000,...           0.027419
# 6     POLYGON Z ((151.02086 -33.97672 0.00000, 151.0...           0.002330
# 7     MULTIPOLYGON Z (((151.09152 -33.94046 0.00000,...           0.000888
# 8     POLYGON Z ((151.03941 -33.88770 0.00000, 151.0...           0.004261
# ...                                                 ...                ...
# 1388  POLYGON Z ((120.01087 -30.96518 0.00000, 120.0...           2.866966
# 1394  MULTIPOLYGON Z (((124.21365 -33.03979 0.00000,...           4.333388
# 1403  POLYGON Z ((118.30270 -33.24537 0.00000, 118.3...           1.147610
# 1421  POLYGON Z ((115.89907 -32.01345 0.00000, 115.8...           0.001891
# 1423  POLYGON Z ((115.89032 -31.95907 0.00000, 115.8...           0.001712
#
#       percentage_overlap
# 1               0.562941
# 3               0.761480
# 6               0.450665
# 7               0.229991
# 8               0.715135
# ...                  ...
# 1388            0.027429
# 1394            0.041458
# 1403            0.010979
# 1421            0.123921
# 1423            0.112191
#
# [556 rows x 10 columns]

# %%
intersection.to_file('../data/curated/GeographicalProportionateData/Elect_LGA.shp')
# Out:
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_72249/2616363507.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   intersection.to_file('../data/curated/GeographicalProportionateData/Elect_LGA.shp')

# %%
intersection[['E_div_numb', 'Elect_div', 'lga_name12', 'lga_code17', 'percentage_overlap']].to_csv('../data/curated/GeographicalProportionateData/Elect_LGA.csv')
