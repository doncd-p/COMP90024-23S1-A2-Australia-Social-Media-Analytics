# %% [markdown]
# # R_9 Twitter Pipeline

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("COMP90024_A2_EDA")
    .config("spark.sql.repl.eagerEval.enabled", True)
    .config("spark.sql.parquet.cacheMetadata", "true")
    .getOrCreate()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/02 13:32:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Read In Original
spark_json = spark.read.json('../data/raw/BigTwitterFile/twitter-huge.json')

# %% [markdown]
# ### Extract Key Columns

# %%
# important features to extract out of the original dataframe
df_selected_columns = spark_json.select('doc._id', 'doc.data.created_at', 'doc.includes', 
                     'doc.data.lang', 'doc.data.text', 'doc.data.author_id')

# %% [markdown]
# ### Missing Geolocation

# %%
from pyspark.sql.functions import col

# Assume `df` is the dataframe that contains the data
column_name = 'includes'
df_drop_no_geo = df_selected_columns.filter(col(column_name).isNotNull())

# %%
df_drop_no_geo.show(5)
# Out:
# +-------------------+--------------------+--------------------+----+--------------------+------------------+
# |                _id|          created_at|            includes|lang|                text|         author_id|
# +-------------------+--------------------+--------------------+----+--------------------+------------------+
# |1491734461951909890|2022-02-10T11:23:...|{"places":[{"full...|  hi|@AshramGzb @Ashra...|858950980989140993|
# |1491734528779763719|2022-02-10T11:23:...|{"places":[{"full...|  hi|@AshramGzb @naren...|858950980989140993|
# |1491567527322808321|2022-02-10T00:19:...|{"places":[{"full...|  en|My life is hittin...|          45472006|
# |1491693811663515654|2022-02-10T08:41:...|{"places":[{"full...|  en|@TobyRayEnglish @...|952342256823943168|
# |1491674087378219009|2022-02-10T07:23:...|{"places":[{"full...|  en|@JadeArchaeobot @...|          25033901|
# +-------------------+--------------------+--------------------+----+--------------------+------------------+
# only showing top 5 rows

# %%
column_name_2 = 'lang'
string_value = 'en'
df_drop_no_geo_eng = df_drop_no_geo.filter(col(column_name_2) == string_value)

# %%
df_drop_no_geo_eng.show(1)
# Out:
# +-------------------+--------------------+--------------------+----+--------------------+---------+
# |                _id|          created_at|            includes|lang|                text|author_id|
# +-------------------+--------------------+--------------------+----+--------------------+---------+
# |1491567527322808321|2022-02-10T00:19:...|{"places":[{"full...|  en|My life is hittin...| 45472006|
# +-------------------+--------------------+--------------------+----+--------------------+---------+
# only showing top 1 row

# %% [markdown]
# ### Extract Tweets containing AI Keywords

# %%
import pandas as pd
words_df = pd.read_excel('../data/raw/Keywords/Voting Keyword.xlsx')

words = list(words_df['keywords'])
words
# Out:
# ['accountab',
#  'advoca',
#  'affirmative action',
#  'agenda setting',
#  'aspiration',
#  'asylum seeker',
#  'bureaucra',
#  'business',
#  'citizen',
#  'class',
#  'colon',
#  'committee',
#  'communit',
#  'conservati',
#  'constitution',
#  'convention',
#  'corrupt',
#  'crisis',
#  'cultur',
#  'culture wars',
#  'federalism',
#  'democracy',
#  'differen',
#  'discourse',
#  'economic rationalis',
#  'egalitarian',
#  'elit',
#  'environment',
#  'equal',
#  'ethic',
#  'ethinic',
#  'executive',
#  'famili',
#  'feminis',
#  'free',
#  'gender',
#  'globalis',
#  'green',
#  'identity',
#  'ideolog',
#  'indigenous',
#  'individual',
#  'interest group',
#  'international relations',
#  'internet',
#  'judicia',
#  'law',
#  'leader',
#  'liberal',
#  'magnagerialism',
#  'mandate',
#  'media',
#  'ministerialadvisers',
#  'minist ',
#  'multicultural',
#  'national identity',
#  'national identity',
#  'obligation',
#  'others',
#  'otherness',
#  'parliament',
#  'participation',
#  'party',
#  'parties',
#  'polic',
#  'political socialisation',
#  'populism',
#  'post-modern',
#  'power',
#  'protest',
#  'public',
#  'public and private',
#  'public opinion',
#  'public sector',
#  'race',
#  'radical',
#  'religion',
#  'represent',
#  'republic',
#  'responsib',
#  'rights',
#  'secularis',
#  'self-determination',
#  'separation of powers',
#  'sexual',
#  'social capital',
#  'fedderalism',
#  'social democratic',
#  'social democrats',
#  'social movement',
#  'socialis',
#  'terroris',
#  'think tank',
#  'third sector',
#  'trade',
#  'tradition',
#  'treat',
#  'union',
#  'utilitarian',
#  'value',
#  'vot',
#  'federalism',
#  'welfare',
#  'westminister']

# %%
from functools import reduce
from pyspark.sql.functions import when, col, instr

# Assume `df` is the dataframe that contains the data
column_name = 'text'
new_column_name = 'is_political'


# Apply `instr` for each keyword and use `reduce` to check if any of them are present
condition = reduce(lambda a, b: a | b, [instr(col(column_name), kw) > 0 for kw in words])

# Use `when` to set the value of the new column based on the condition
df_drop_no_geo_eng_withPolCol = df_drop_no_geo_eng.withColumn(new_column_name, when(condition, 1).otherwise(0))

# %%
from pyspark.sql.functions import substring, to_date

# Assuming your DataFrame is named `df` and the string column is named `string_col`
df_drop_no_geo_eng_withPolCol_date = df_drop_no_geo_eng_withPolCol.withColumn("date", to_date(substring("created_at", 1, 10)))

# %%
df_drop_no_geo_eng_withPolCol_date.show(5)
# Out:
# +-------------------+--------------------+--------------------+----+--------------------+-------------------+------------+----------+
# |                _id|          created_at|            includes|lang|                text|          author_id|is_political|      date|
# +-------------------+--------------------+--------------------+----+--------------------+-------------------+------------+----------+
# |1491567527322808321|2022-02-10T00:19:...|{"places":[{"full...|  en|My life is hittin...|           45472006|           0|2022-02-10|
# |1491693811663515654|2022-02-10T08:41:...|{"places":[{"full...|  en|@TobyRayEnglish @...| 952342256823943168|           0|2022-02-10|
# |1491674087378219009|2022-02-10T07:23:...|{"places":[{"full...|  en|@JadeArchaeobot @...|           25033901|           0|2022-02-10|
# |1491721359587627008|2022-02-10T10:31:...|{"places":[{"full...|  en|@JadeArchaeobot @...|         3103790508|           0|2022-02-10|
# |1491595343838220291|2022-02-10T02:10:...|{"places":[{"full...|  en|@BehnamAkhavan @E...|1249497357944672257|           0|2022-02-10|
# +-------------------+--------------------+--------------------+----+--------------------+-------------------+------------+----------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import regexp_extract

# Assuming your DataFrame is named `df` and the string column is named `string_col`
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date.withColumn("coord", regexp_extract("includes", r"(-?\d+\.\d+,-?\d+\.\d+,-?\d+\.\d+,-?\d+\.\d+)", 1))

# %%
from pyspark.sql.functions import split

# Assuming your DataFrame is named `df` and the string column is named `string_col`
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("x1", split("coord", ",").getItem(0).cast('float'))
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("y1", split("coord", ",").getItem(1).cast('float'))
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("x2", split("coord", ",").getItem(2).cast('float'))
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("y2", split("coord", ",").getItem(3).cast('float'))

# %%
from pyspark.sql.functions import mean

# Assuming your DataFrame is named `df` and the two columns are named `col1` and `col2`
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("x_cent", (df_drop_no_geo_eng_withPolCol_date_coord["x1"] + df_drop_no_geo_eng_withPolCol_date_coord["x2"]) / 2)
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.withColumn("y_cent", (df_drop_no_geo_eng_withPolCol_date_coord["y1"] + df_drop_no_geo_eng_withPolCol_date_coord["y2"]) / 2)

# %%
df_drop_no_geo_eng_withPolCol_date_coord = df_drop_no_geo_eng_withPolCol_date_coord.select('_id', 'date', 'x_cent', 'y_cent', 
                     'text', 'author_id', 'is_political')

# %%
# Assuming your DataFrame is named `df` and you want to save it in a directory named `output_directory`
df_drop_no_geo_eng_withPolCol_date_coord.write.format("parquet").mode("overwrite").save("../data/curated/Twitter/twitter.parquet")

# %%
import pandas as pd

df = pd.read_parquet('../data/curated/Twitter/twitter.parquet')

# %%
df
# Out:
#                          _id        date      x_cent     y_cent  \
# 0        1491567527322808321  2022-02-10  150.520142 -23.339474
# 1        1491693811663515654  2022-02-10  153.369354 -27.954222
# 2        1491674087378219009  2022-02-10  151.926880 -27.573589
# 3        1491721359587627008  2022-02-10  115.928314 -32.150101
# 4        1491595343838220291  2022-02-10  150.931976 -33.848244
# ...                      ...         ...         ...        ...
# 2517272  1557517139002925056  2022-08-10  144.954147 -37.824257
# 2517273  1557448918329266176  2022-08-10  152.993195 -27.382143
# 2517274  1557499571642593280  2022-08-10  150.931976 -33.848244
# 2517275  1557502623947030528  2022-08-10  150.931976 -33.848244
# 2517276  1557495250264158208  2022-08-10  145.053131 -37.972565
#
#                                                       text  \
# 0        My life is hitting a big change soon. Keen to ...
# 1        @TobyRayEnglish @MikeDel21893959 @aSinister @b...
# 2                    @JadeArchaeobot @HarvardGSAS oh ewwww
# 3        @JadeArchaeobot @HarvardGSAS I'm so sorry you ...
# 4        @BehnamAkhavan @EngAustralia @Eng_IT_Sydney @S...
# ...                                                    ...
# 2517272  Day two has kicked off #EduTECHAU!\n\nMeet our...
# 2517273  @bluboy43 @TaikaWaititi People will still like...
# 2517274          @AMCELL @puck_fair What’s happening here?
# 2517275                     @AMCELL @puck_fair That’s sad.
# 2517276  @jhgates1 @Climatehope2 @S_D_Mannix @Mark_A_Lu...
#
#                    author_id  is_political
# 0                   45472006             0
# 1         952342256823943168             0
# 2                   25033901             0
# 3                 3103790508             0
# 4        1249497357944672257             0
# ...                      ...           ...
# 2517272  1468040114781655040             0
# 2517273             20742804             0
# 2517274           1010068200             0
# 2517275           1010068200             0
# 2517276           1310276082             0
#
# [2517277 rows x 7 columns]

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import numpy as np

def get_sentiment(x):

    sia = SentimentIntensityAnalyzer()

    sia_out = sia.polarity_scores(x)

    neg = sia_out['neg']
    pos = sia_out['pos']
    compound = sia_out['compound']

    sentiment = np.argmax({-1:sia_out['neg'], 0: sia_out['neu'], 1:sia_out['pos']})

    return neg, pos, compound, sentiment

# %%
df[["neg_score", "pos_score", "compound_score", "sentiment"]] = df["text"].apply(lambda x: pd.Series(get_sentiment(x)))

# %%
df.to_parquet('../data/curated/twitter_with_sent.parquet')

# %%
df[df['is_political']==1]
# Out:
#                          _id        date      x_cent     y_cent  \
# 8        1491795863018274816  2022-02-10  152.993195 -27.382143
# 15       1491725195375439877  2022-02-10  152.993195 -27.382143
# 24       1491648779082100739  2022-02-10  150.931976 -33.848244
# 31       1491626908106190848  2022-02-10  145.053131 -37.972565
# 53       1491588166888742912  2022-02-10  145.053131 -37.972565
# ...                      ...         ...         ...        ...
# 2517233  1557514633623191553  2022-08-10  152.993195 -27.382143
# 2517243  1557515011781640193  2022-08-10  152.400208 -27.636768
# 2517255  1557515835237072896  2022-08-10  144.952393 -37.824680
# 2517256  1557515963662077953  2022-08-10  152.993195 -27.382143
# 2517260  1557516252821995521  2022-08-10  151.199951 -33.875137
#
#                                                       text  \
# 8        @IMmadashellandi @HeshmatAlavi Israel is a dem...
# 15       @stilllukebowden More power to Barbara, Sue an...
# 24       @Dr_eVal @Sg3912 @parsleysmum @ardentgreeneyes...
# 31       @sammyjcomedian @NikkiKlopfer Another reclaime...
# 53       @MattGurchenko @MrInbetween1 @Garyandthegoat1 ...
# ...                                                    ...
# 2517233  Trump Attorney wasn’t allowed presence when KG...
# 2517243        Mod parties be like https://t.co/jm21gF9qIy
# 2517255  "Teacher's need to start where they're comfort...
# 2517256  Laid back  sleeping ordinary undecided conserv...
# 2517260  What an amazing start to the #CAA #womeninlead...
#
#                    author_id  is_political  neg_score  pos_score  \
# 8                 4516171573             1      0.228      0.000
# 15                 177543302             1      0.000      0.000
# 24        987281520099344384             1      0.107      0.030
# 31                 418231895             1      0.000      0.372
# 53       1466177366506549251             1      0.000      0.000
# ...                      ...           ...        ...        ...
# 2517233  1511175941846102021             1      0.144      0.000
# 2517243            803641382             1      0.000      0.634
# 2517255           1074293586             1      0.000      0.000
# 2517256  1511175941846102021             1      0.118      0.000
# 2517260   747013936931700736             1      0.000      0.337
#
#          compound_score  sentiment
# 8               -0.7955        0.0
# 15               0.0000        0.0
# 24              -0.6876        0.0
# 31               0.8360        0.0
# 53               0.0000        0.0
# ...                 ...        ...
# 2517233         -0.7096        0.0
# 2517243          0.6369        0.0
# 2517255          0.0000        0.0
# 2517256         -0.4710        0.0
# 2517260          0.7650        0.0
#
# [307585 rows x 11 columns]

# %%
df['pos_sentiment'] = df['pos_score']>df['neg_score']

# %%
df
# Out:
#                          _id        date      x_cent     y_cent  \
# 0        1491567527322808321  2022-02-10  150.520142 -23.339474
# 1        1491693811663515654  2022-02-10  153.369354 -27.954222
# 2        1491674087378219009  2022-02-10  151.926880 -27.573589
# 3        1491721359587627008  2022-02-10  115.928314 -32.150101
# 4        1491595343838220291  2022-02-10  150.931976 -33.848244
# ...                      ...         ...         ...        ...
# 2517272  1557517139002925056  2022-08-10  144.954147 -37.824257
# 2517273  1557448918329266176  2022-08-10  152.993195 -27.382143
# 2517274  1557499571642593280  2022-08-10  150.931976 -33.848244
# 2517275  1557502623947030528  2022-08-10  150.931976 -33.848244
# 2517276  1557495250264158208  2022-08-10  145.053131 -37.972565
#
#                                                       text  \
# 0        My life is hitting a big change soon. Keen to ...
# 1        @TobyRayEnglish @MikeDel21893959 @aSinister @b...
# 2                    @JadeArchaeobot @HarvardGSAS oh ewwww
# 3        @JadeArchaeobot @HarvardGSAS I'm so sorry you ...
# 4        @BehnamAkhavan @EngAustralia @Eng_IT_Sydney @S...
# ...                                                    ...
# 2517272  Day two has kicked off #EduTECHAU!\n\nMeet our...
# 2517273  @bluboy43 @TaikaWaititi People will still like...
# 2517274          @AMCELL @puck_fair What’s happening here?
# 2517275                     @AMCELL @puck_fair That’s sad.
# 2517276  @jhgates1 @Climatehope2 @S_D_Mannix @Mark_A_Lu...
#
#                    author_id  is_political  neg_score  pos_score  \
# 0                   45472006             0      0.052      0.244
# 1         952342256823943168             0      0.000      0.067
# 2                   25033901             0      0.000      0.000
# 3                 3103790508             0      0.162      0.000
# 4        1249497357944672257             0      0.000      0.406
# ...                      ...           ...        ...        ...
# 2517272  1468040114781655040             0      0.000      0.275
# 2517273             20742804             0      0.000      0.200
# 2517274           1010068200             0      0.000      0.000
# 2517275           1010068200             0      0.508      0.000
# 2517276           1310276082             0      0.026      0.129
#
#          compound_score  sentiment  pos_sentiment
# 0                0.7412        0.0           True
# 1                0.4767        0.0           True
# 2                0.0000        0.0          False
# 3               -0.1880        0.0          False
# 4                0.6249        0.0           True
# ...                 ...        ...            ...
# 2517272          0.9167        0.0           True
# 2517273          0.3612        0.0           True
# 2517274          0.0000        0.0          False
# 2517275         -0.4767        0.0          False
# 2517276          0.8720        0.0           True
#
# [2517277 rows x 12 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point

# Load the GeoPandas polygon data
polygon_gdf = gpd.read_file("../data/raw/Geography/2021_ELB_region.shp")

# %%
polygon_gdf
# Out:
#      E_div_numb  Elect_div  Numccds  Actual  Projected  Total_Popu  \
# 0             1      Banks      359       0          0           0
# 1             2     Barton      386       0          0           0
# 2             3  Bennelong      364       0          0           0
# 3             4    Berowra      389       0          0           0
# 4             5   Blaxland      419       0          0           0
# ..          ...        ...      ...     ...        ...         ...
# 146          11   O'Connor      543  114035     113375           0
# 147          12     Pearce      345  106306     118884           0
# 148          13      Perth      394  116242     118518           0
# 149          14       Swan      418  114942     117373           0
# 150          15    Tangney      411  117986     120085           0
#
#      Australian   Area_SqKm   Sortname  \
# 0             0       49.47      Banks
# 1             0       39.65     Barton
# 2             0       58.76  Bennelong
# 3             0      741.64    Berowra
# 4             0       61.16   Blaxland
# ..          ...         ...        ...
# 146           0  1126936.75   O'Connor
# 147           0      782.75     Pearce
# 148           0       79.92      Perth
# 149           0      150.89       Swan
# 150           0      101.97    Tangney
#
#                                               geometry
# 0    POLYGON Z ((151.12967 -33.97363 0.00000, 151.1...
# 1    POLYGON Z ((151.17424 -33.92497 0.00000, 151.1...
# 2    POLYGON Z ((151.15908 -33.79871 0.00000, 151.1...
# 3    POLYGON Z ((151.28480 -33.57221 0.00000, 151.2...
# 4    POLYGON Z ((151.04441 -33.84205 0.00000, 151.0...
# ..                                                 ...
# 146  MULTIPOLYGON Z (((129.00205 -30.76778 0.00000,...
# 147  POLYGON Z ((115.98284 -31.74189 0.00000, 115.9...
# 148  POLYGON Z ((115.96432 -31.88769 0.00000, 115.9...
# 149  POLYGON Z ((116.04102 -31.98350 0.00000, 116.0...
# 150  POLYGON Z ((115.95162 -32.08277 0.00000, 115.9...
#
# [151 rows x 10 columns]

# %%
# Convert the coordinate column to a Point GeoSeries
df["point"] = df.apply(lambda row: Point(row["x_cent"], row["y_cent"]), axis=1)
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
def get_Electorate(coord):
    for idx, polygon in polygon_gdf.iterrows():
        if polygon.geometry.contains(coord):
            return polygon['Elect_div']
    
    return None

# %%
df["electorate"] = df["point"].apply(get_Electorate)
# Out:
# 23/05/03 04:03:59 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 919013 ms exceeds timeout 120000 ms
# 23/05/03 04:04:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_8899/3405076597.py in <module>
# ----> 1 df["electorate"] = df["point"].apply(get_Electorate)
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/xg/8w_3dndd6l5c3n99vd7vd3f40000gn/T/ipykernel_8899/1097705998.py in get_Electorate(coord)
#       1 def get_Electorate(coord):
# ----> 2     for idx, polygon in polygon_gdf.iterrows():
#       3         if polygon.geometry.contains(coord):
#       4             return polygon['Elect_div']
#       5
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in iterrows(self)
#    1321         columns = self.columns
#    1322         klass = self._constructor_sliced
# -> 1323         for k, v in zip(self.index, self.values):
#    1324             s = klass(v, index=columns, name=k)
#    1325             yield k, s
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in values(self)
#   10890         """
#   10891         self._consolidate_inplace()
# > 10892         return self._mgr.as_array()
#   10893
#   10894     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1597                     arr = arr.astype(dtype, copy=False)
#    1598         else:
# -> 1599             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1600             # The underlying data was copied within _interleave
#    1601             copy = False
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1644             for blk in self.blocks:
#    1645                 rl = blk.mgr_locs
# -> 1646                 arr = blk.get_values(dtype)
#    1647                 result[rl.indexer] = arr
#    1648                 itemmask[rl.indexer] = 1
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in get_values(self, dtype)
#    1467         values: ArrayLike = self.values
#    1468         if dtype == _dtype_obj:
# -> 1469             values = values.astype(object)
#    1470         # TODO(EA2D): reshape not needed with 2D EAs
#    1471         return np.asarray(values).reshape(self.shape)
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/array.py in astype(self, dtype, copy)
#    1060             return string_values.astype(dtype, copy=False)
#    1061         else:
# -> 1062             return np.array(self, dtype=dtype, copy=copy)
#    1063
#    1064     def isna(self):
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/array.py in __array__(self, dtype)
#    1329         values : numpy array
#    1330         """
# -> 1331         return to_shapely(self)
#    1332
#    1333     def _binop(self, other, op):
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/array.py in to_shapely(geoms)
#     157     if not isinstance(geoms, GeometryArray):
#     158         raise ValueError("'geoms' must be a GeometryArray")
# --> 159     return vectorized.to_shapely(geoms.data)
#     160
#     161
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py in to_shapely(data)
#     152         out = np.empty(len(data), dtype=object)
#     153         with compat.ignore_shapely2_warnings():
# --> 154             out[:] = [_pygeos_to_shapely(geom) for geom in data]
#     155         return out
#     156     else:
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py in <listcomp>(.0)
#     152         out = np.empty(len(data), dtype=object)
#     153         with compat.ignore_shapely2_warnings():
# --> 154             out[:] = [_pygeos_to_shapely(geom) for geom in data]
#     155         return out
#     156     else:
#
# /Applications/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py in _pygeos_to_shapely(geom)
#      77         return shapely.wkt.loads("POINT EMPTY")
#      78     else:
# ---> 79         return shapely.wkb.loads(pygeos.to_wkb(geom))
#      80
#      81
#
# /Applications/anaconda3/lib/python3.9/site-packages/pygeos/io.py in to_wkb(geometry, hex, output_dimension, byte_order, include_srid, **kwargs)
#     232         raise TypeError("include_srid only accepts scalar values")
#     233
# --> 234     return lib.to_wkb(
#     235         geometry,
#     236         np.bool_(hex),
#
# KeyboardInterrupt:
# 23/05/03 12:40:01 WARN TransportChannelHandler: Exception in connection from /192.168.3.86:50048
# java.io.IOException: Operation timed out
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:350)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:722)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:658)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:584)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:496)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:986)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.lang.Thread.run(Thread.java:750)

# %%
df.to_parquet('../data/curated/twitter_with_sent_electorate.parquet')
